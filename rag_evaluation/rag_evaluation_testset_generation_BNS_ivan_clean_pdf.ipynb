# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://docs.ragas.io/en/stable/) (```v 0.1.22```) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [LangChain](https://python.langchain.com/docs/introduction/) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# ### <u>Requirements</u>
# 1. As you will accessing the LLMs and embedding models through Vector AI Engineering's Kaleidoscope Service (Vector Inference + Autoscaling), you will need to request a KScope API Key:
#
#       Run the following command (replace ```<user_id>``` and ```<password>```) from **within the cluster** to obtain the API Key. The ```access_token``` in the output is your KScope API Key.
#   ```bash
#   curl -X POST -d "grant_type=password" -d "username=<user_id>" -d "password=<password>" https://kscope.vectorinstitute.ai/token
#   ```
# 2. After obtaining the `.env` configurations, make sure to create the ```.kscope.env``` file in your home directory (```/h/<user_id>```) and set the following env variables:
# - For local models through Kaleidoscope (KScope):
#     ```bash
#     export OPENAI_BASE_URL="https://kscope.vectorinstitute.ai/v1"
#     export OPENAI_API_KEY=<kscope_api_key>
#     ```
# - For OpenAI models:
#    ```bash
#    export OPENAI_BASE_URL="https://api.openai.com/v1"
#    export OPENAI_API_KEY=<openai_api_key>
#    ```

# %% [markdown]
# ## Set up the RAG workflow environment

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install pdfplumber

# %%
#import pdfplumber

# %%
import numpy as np
import os
import sys

from datasets import Dataset
from pathlib import Path

from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from ragas.testset import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# #### Load config files

# %%
# Add root folder of the rag_bootcamp repo to PYTHONPATH
current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.insert(0, str(parent_dir))

# %%
from utils.load_secrets import load_env_file
load_env_file()

# %% [markdown]
# #### Set up some helper functions

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# #### Make sure other necessary items are in place

# %%
# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# #### Start by loading in the documents we'll be using to augment our RAG generations

# %%
#loader = PyPDFDirectoryLoader(documents_path)
#documents = loader.load()
#for document in documents:
#    document.metadata['file_name'] = document.metadata['source']
    
#%%time
# Load the IBIS pdfs
#directory_path = "./source_documents"
directory_path = "/projects/RAG2/scotia-2/Datasets-Scotia-2/IBIS"
loader = PyPDFDirectoryLoader(directory_path)
docs = loader.load()
print(f"Number of source documents: {len(docs)}")
for document in docs:
    document.metadata['file_name'] = document.metadata['source']
# Split the documents into smaller chunks
#text_splitter = RecursiveCharacterTextSplitter(chunk_size=3600, chunk_overlap=32)
#chunks = text_splitter.split_documents(docs)
#print(f"Number of text chunks: {len(chunks)}")
# Out:
# Number of source documents: 280

# %%
from langchain.document_loaders import TextLoader

# %%
directory_path  ='/projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text'

documents=[]
for filename in os.listdir(directory_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory_path, filename)
        print (file_path)
        loader = TextLoader(file_path)

        # Load the document

        document = loader.load()
        documents = documents+ document
        #chunks2 =text_splitter.split_documents(document)
        #print(f"Number of text chunks: {len(chunks2)}")
        #chunks= chunks +chunks2
# Out:
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/11114CA Wheat Farming in Canada Industry Report.txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/48422CA Local Specialized Freight Trucking in Canada Industry Report.txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/44111CA New Car Dealers in Canada Industry Report.txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/48412CA Long-Distance Freight Trucking in Canada Industry Report.txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/33639CA Auto Parts Manufacturing in Canada Industry Report.txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/48423CA Long-Distance Specialized Freight Trucking in Canada Industry .txt
# /projects/RAG2/scotia-2/Datasets-Scotia-2/PDF_text/11115CA Corn Farming in Canada Industry Repor.txt

# %%
type(document)
# Out:
# list

# %% [markdown]
# #### Now use OpenAI to generate a test set from the data in these documents (This takes about 2-3 minutes)

# %% [markdown]
# **IMP Note:** The LLM and embedding model used for test set generation should be more capable than the model being evaluated. Hence, we will use OpenAI GPT-4o and OpenAI embeddings for this purpose.
#
# Store your OpenAI API key in ```~/.ragas_openai.env``` using the following format (this is in addition to ```~/.kscope.env```):
#
# ```bash
# export RAGAS_OPENAI_BASE_URL="https://api.openai.com/v1"
# export RAGAS_OPENAI_API_KEY=<openai_api_key>
# ```

# %%
from utils.load_secrets import load_env_file_ragas
load_env_file_ragas()

# %%
generator_llm = ChatOpenAI(
    model="gpt-4o",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)
generator_embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)

# %%
#generator_llm = (
#    model="DeepSeek-R1-Distill-Llama-8B",
#    base_url=os.environ["OPENAI_BASE_URL"],
#    api_key=os.environ["OPENAI_API_KEY"],
#)
# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity
print(f"Setting up the RAG LLM...")
llm = ChatOpenAI(
    #model="DeepSeek-R1-Distill-Llama-8B",
    model="Meta-Llama-3.1-8B-Instruct",
    temperature=0,
    max_tokens=256,
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# Setting up the RAG LLM...

# %%
# %%time
# Create generator with OpenAI model
generator = TestsetGenerator.from_langchain(
    generator_llm=llm,
    critic_llm=llm,
    embeddings=embeddings,
)

# Generate the test set
testset = generator.generate_with_langchain_docs(
    documents=documents, 
    test_size=50,
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25},
)
# Out:
# embedding nodes:   0%|          | 0/260 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/50 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# CPU times: user 35.4 s, sys: 1.92 s, total: 37.4 s
# Wall time: 8min 30s

# %% [markdown]
# #### Preview the test dataset so far

# %%
testset1 = testset.to_pandas()

# %%
# testset1.to_parquet ('../../Testing_Data/testset_llama.parquet')
# testset1.to_csv ('../../Testing_Data/testset_llama.csv', index =False)

# %%
import joblib

# Save (serialize) the object to a file
joblib.dump(testset, "../../Testing_Data/testset_openai_clean.pkl")
# Out:
# ['../../Testing_Data/testset_openai_clean.pkl']

# %%
testset1.to_parquet ('../../Testing_Data/testset_openai_clean.parquet')
testset1.to_csv ('../../Testing_Data/testset_openai_clean.csv', index =False)

# %%
#load 
# Load (deserialize) the object from file
testset2 = joblib.load("../../Testing_Data/testset_openai_clean.pkl")

# %%
print (testset==testset2)
# Out:
# True

# %% [markdown]
# ## Now, start the RAG pipeline!

# %% [markdown]
# #### Choose the RAG LLM and embedding model
# Note: This is different than the OpenAI LLM and embedding model defined above for test set generation.

# %%
RAG_LLM_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
RAG_EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# %% [markdown]
# #### Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2500, chunk_overlap=32)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")
# Out:
# Number of text chunks: 233

# %%
# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name=RAG_EMBEDDING_MODEL_NAME,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# Setting up the RAG embeddings model...

# %%
# Create the vector store and the retriever
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %%
RAG_LLM_MODEL_NAME
# Out:
# 'Meta-Llama-3.1-8B-Instruct'

# %%
# %%time
# Define the RAG LLM (different than the OpenAI LLM defined above for test set generation)
print(f"Setting up the RAG LLM...")
llm = ChatOpenAI(
    model=RAG_LLM_MODEL_NAME,
    temperature=0,
    max_tokens=256,
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)
# Out:
# Setting up the RAG LLM...
# CPU times: user 12.6 ms, sys: 7.32 ms, total: 19.9 ms
# Wall time: 19.1 ms

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned. (This also takes 2-3 minutes)

# %%
# %%time
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Run the query through the RAG pipeline
    rag_pipeline = RetrievalQA.from_llm(
        llm=llm,
        retriever=retriever
    )
    answer = rag_pipeline.invoke(input=query)
    answer = answer["result"]
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
    
    # Store the result
    answers[index] = answer
# Out:
# Result 0
# Question: Here is a question that can be fully answered from the given context:
#
# "What drives the demand for dry bulk transportation in the local specialized freight trucking industry in Canada?"
#
# This question can be answered by referencing the context, which states that "Dry bulk transportation swells alongside construction activity" and that "Strong construction activity has supported this segment but is expected to trend downward through the end of 2024 as tightened monetary policy pressures businesses' financing ability.
# Answer: The demand for dry bulk transportation in the local specialized freight trucking industry in Canada is driven by construction activity.
#
# Result 1
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the expected outcomes of the government's pro-immigration policies on the driver shortage and turnover in the long-distance specialized freight trucking industry in Canada?
# Answer: The expected outcomes of the government's pro-immigration policies on the driver shortage and turnover in the long-distance specialized freight trucking industry in Canada are to alleviate pressure from high driver turnover and vacancies. The Express Entry initiative is expected to expedite immigration, enabling migrant workers to arrive in Canada within six months of applying, which will help to quickly bring in new truckers to replace retiring employees and those not keen on the trucker lifestyle.
#
# Result 2
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the expected impact of the rebound in economic growth on the demand for freight transportation services in Canada?
# Answer: The rebound in economic growth is expected to boost demand for freight transportation services in Canada, driven by increased consumer spending and construction investments. The rebounding demand will prompt manufacturers to enhance production, prompting freight companies to expand operations.
#
# Result 3
# Question: Here is a question that can be fully answered from the given context using the topic "E-commerce growth":
#
# question: "What is driving the growth of e-commerce in the long-distance freight trucking industry in Canada?
# Answer: According to the context, the growth of e-commerce is driving the growth of the long-distance freight trucking industry in Canada. Specifically, it is mentioned that "Resilient consumer spending supported growth in freight trucking companies despite economic volatility. As more consumers shop online and source goods globally, demand for parcel transport has increased, leading to higher revenues for the sector." This suggests that the shift to online shopping and e-commerce is driving the growth of the industry.
#
# Result 4
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the average debt ratio of corn farming enterprises in Canada, based on the data from 2018 to 2022?
# Answer: To calculate the average debt ratio of corn farming enterprises in Canada, we need to look at the debt ratio for each year from 2018 to 2022.
#
# According to the context, the debt ratio for each year is as follows:
#
# * 2018: 0.6
# * 2019: 0.6
# * 2020: 0.6
# * 2021: 0.6
# * 2022: 0.5
#
# To calculate the average debt ratio, we can add up the debt ratios for each year and divide by the number of years:
#
# (0.6 + 0.6 + 0.6 + 0.6 + 0.5) / 5 = 0.58
#
# So, the average debt ratio of corn farming enterprises in Canada, based on the data from 2018 to 2022, is 0.58.
#
# Result 5
# Question: Here is a question that can be fully answered from the given context:
#
# "What province in Canada has the majority of new car dealerships and auto parts manufacturers?"
#
# This question can be answered by looking at the tables and text in the context, which state that Ontario has the majority of new car dealerships and auto parts manufacturers, and that it is the province with the largest spread of businesses compared to its population.
# Answer: The province in Canada with the majority of new car dealerships and auto parts manufacturers is Ontario.
#
# Result 6
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the key factors that successful businesses in the specialized trucking services industry use to compete with substitutes such as rail transportation and air transportation?
# Answer: According to the context, the key factors that successful businesses in the specialized trucking services industry use to compete with substitutes such as rail transportation and air transportation are:
#
# 1. Develop strong technical product knowledge
# 2. Provide superior after-sales service
# 3. Ensure appropriate pricing policy
# 4. Optimize operating capacity
# 5. Ensure skilled labor is available
#
# These factors help trucking companies to differentiate themselves from substitutes, improve service quality, and maintain a competitive edge in the market.
#
# Result 7
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the key factors that successful businesses in the specialized trucking services industry use to compete with substitutes such as rail transportation and air transportation?
# Answer: According to the context, the key factors that successful businesses in the specialized trucking services industry use to compete with substitutes such as rail transportation and air transportation are:
#
# 1. Develop strong technical product knowledge
# 2. Provide superior after-sales service
# 3. Ensure appropriate pricing policy
# 4. Optimize operating capacity
# 5. Ensure skilled labor is available
#
# These factors help trucking companies to differentiate themselves from substitutes, improve service quality, and maintain a competitive edge in the market.
#
# Result 8
# Question: Here is a question that can be fully answered from the given context:
#
# "What type of research does IBISWorld specialize in?
# Answer: IBISWorld specializes in industry research with coverage on thousands of global industries.
#
# Result 9
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the expected long-term effects of rising truck prices and fuel costs on the Long-Distance Specialized Freight Trucking industry in Canada?
# Answer: According to the context, the expected long-term effects of rising truck prices and fuel costs on the Long-Distance Specialized Freight Trucking industry in Canada are:
#
# * Lower revenue generated per trip due to higher vehicle weight, which is expected to be 5,000 pounds heavier for electric trucks compared to diesel-powered trucks.
# * Reduced cargo capacity, as higher vehicle weight will limit the amount of cargo that can be transported before breaching weight-limit regulations.
# * Lower profitability for truckers, as they will have to absorb the higher costs of fuel and truck maintenance.
# * Potential for consolidation among larger carriers, as smaller competitors may be forced out of the industry due to their inability to pass on fuel costs to customers.
# * Increased competition from railroads, which tend to outperform during rising oil prices due to their economies of scale.
#
# However, it's worth noting that the context also mentions that a decline in fuel costs will positively impact the industry, as it will lower operating expenses and boost profits for truckers.
#
# Result 10
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the key international markets that drive demand for Canadian corn exports?"
#
# This question can be answered by referencing the context, which states that "Demand from key international markets drives corn exports" and specifically mentions Ireland, the US, and the United Kingdom as key markets.
# Answer: The key international markets that drive demand for Canadian corn exports are Ireland, the US, and the United Kingdom.
#
# Result 11
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the expected trends in the Canadian long-distance specialized freight trucking industry, including the impact of technological advances and government policies?"
#
# This question is fully answerable from the context, which discusses the industry's expected growth, the impact of technological advances, the effects of government policies such as the Express Entry initiative, and the industry's maturity and saturation levels.
# Answer: Based on the provided context, the expected trends in the Canadian long-distance specialized freight trucking industry include:
#
# 1. Revenue expansion: The industry is expected to experience revenue growth due to the rebound in economic growth, increased consumer spending, and rising private and construction investment levels.
# 2. Technological advances: The industry will continue to invest in remote monitoring systems, technology to strengthen resilience, and autonomous or semi-autonomous trucks to mitigate labor shortages. Autonomous trucks are expected to operate an estimated 78.0% of the time, compared to the current 29.0%.
# 3. Government policies: The Express Entry initiative will help alleviate pressure from high driver turnover by expediting immigration and enabling migrant workers to arrive in Canada within six months of applying.
# 4. Increased competition: New entrants into the market will continue to spur competition, leading to further consolidation among the industry's largest carriers.
# 5. Investment in electric vehicles: Freight trucking companies will aim to acquire hybrid, battery, and plug-in electric vehicles to advertise a more environmentally friendly fleet and remove the uncertainty of fuel prices and unfavorable regulations targeting fuel efficiency in vehicles.
# 6. Improved safety: Companies will prioritize the safety of drivers during long-haul routes by investing in fleets and equipping vehicles with the latest technology, such as
# Result 12
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the expected Compound Annual Growth Rate (CAGR) of revenue for local specialized freight trucking companies in Canada through the end of 2029?
# Answer: The expected Compound Annual Growth Rate (CAGR) of revenue for local specialized freight trucking companies in Canada through the end of 2029 is 1.5%.
#
# Result 13
# Question: Here is a question that can be fully answered from the given context:
#
# "According to the Electric Vehicle Availability Standard, what percentage of new cars, SUVs, crossovers, and light-duty pickup trucks sold in Canada must be 100% zero-emission by 2035?"
#
# This question can be answered directly from the context, which states: "Canada unveiled the Electric Vehicle Availability Standard, requiring all new cars, SUVs, crossovers and light-duty pickup trucks sold in Canada to be 100% zero-emission by 2035.
# Answer: According to the Electric Vehicle Availability Standard, 100% of new cars, SUVs, crossovers, and light-duty pickup trucks sold in Canada must be 100% zero-emission by 2035.
#
# Result 14
# Question: Here is a question that can be fully answered from the given context:
#
# "By what percentage did the number of enterprises in the Long-Distance Freight Trucking industry in Canada increase from 2006 to 2007?"
#
# This question can be answered by looking at the "Enterprises" column in the table, where it shows a 17% increase from 2006 to 2007.
# Answer: The question cannot be answered from the given context because the context only mentions the year 2007, but does not provide any information about the number of enterprises in 2006.
#
# Result 15
# Question: Here is a question that can be fully answered from the given context:
#
# "Keyphrase: 'Strong market profile'
# question: "How does establishing a strong market presence affect buyer power in the long-distance freight trucking industry in Canada?
# Answer: According to the context, establishing a strong market presence enhances brand recognition and customer loyalty, which reduces buyer power by making the service a preferred choice, lessening the impact of competitive offers in the market.
#
# Result 16
# Question: Here is a question that can be fully answered from the given context:
#
# "Over the period from 2005 to 2030, what was the average annual percentage change in the number of establishments in the Long-Distance Freight Trucking industry in Canada?"
#
# This question can be answered by analyzing the data in the "Industry Data Annual Change" section of the context, specifically the column labeled "%" under the "Establishments" heading.
# Answer: Unfortunately, the context provided does not include data on the number of establishments from 2005 to 2030. The data only goes up to 2028, and the context does not provide a clear way to calculate the average annual percentage change over the entire period.
#
# However, I can answer a related question based on the available data. According to the "Business" section of the context, the number of businesses in the Long-Distance Freight Trucking industry in Canada is expected to increase at an average annual rate of 1.3% from 2019 to 2024, and then remain at that rate from 2024 to 2029.
#
# Result 17
# Question: Here is a question that can be fully answered from the given context:
#
# "How do fuel costs and pricing power affect the profitability of long-distance specialized freight trucking companies in Canada?
# Answer: Fuel costs and pricing power have a significant impact on the profitability of long-distance specialized freight trucking companies in Canada. High fuel costs limit profit and push companies to raise transportation rates to compensate. However, the industry's competitive nature prevents businesses from fully passing costs downstream, forcing them to absorb parts of the cost. This is particularly true for general freight truckers who don't enjoy the same pricing power as specialized truckers, such as those who transport reefers, dry vans, and oil tankers. Surcharges allow truckers to pass rising fuel costs downstream to their clients, but the competitive pricing landscape prevents them from fully benefiting from fuel spikes. As a result, rising fuel prices have halted profit expansion and pressured tankers and reefers, although less than general freight truckers.
#
# Result 18
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the forecasted revenue growth rate for the Long-Distance Specialized Freight Trucking industry in Canada from 2019-2024?"
#
# This question can be answered by looking at the table that shows the forecasted annual revenue and change percentage for the industry from 2012 to 2028. The answer can be found in the row that says "Revenue" and the column that says "â19-â24 î¥0.5 %", which indicates a revenue growth rate of 0.5% from 2019 to 2024.
# Answer: The forecasted revenue growth rate for the Long-Distance Specialized Freight Trucking industry in Canada from 2019-2024 is 0.5%.
#
# Result 19
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the expected impact of the rebound in economic growth on the demand for freight transportation services in Canada?
# Answer: The rebound in economic growth is expected to boost demand for freight transportation services in Canada, driven by increased consumer spending and construction investments. The rebounding demand will prompt manufacturers to enhance production, prompting freight companies to expand operations.
#
# Result 20
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the effect of low barriers to entry on the long-distance freight trucking industry in Canada?
# Answer: Low barriers to entry in the long-distance freight trucking industry in Canada have kept the market competitive. Minimal capital requirements allow individuals to easily start a business, fostering an expansion in nonemployer establishments. This has resulted in the addition of more than 5,000 nonemployer establishments since 2018. The presence of freight brokerages and agencies facilitating contracts with clients also supports the entry of nonemployers, keeping the concentration low.
#
# Result 21
# Question: Here is a question that can be fully answered from the given context using the keyphrase "Barriers to Entry":
#
# "What challenges do potential industry entrants face when entering the local specialized freight trucking industry in Canada?"
#
# This question is fully answerable from the context, as it is directly addressed in the section "What challenges do potential industry entrants face?" under the subheading "Barriers to Entry".
# Answer: According to the context, potential industry entrants in the local specialized freight trucking industry in Canada face the following challenges:
#
# * Legal: New entrants must comply with stringent Canadian transportation regulations.
# * Start-Up Costs: While the costs are not specified, it is mentioned that local specialized freight truckers have historically specialized in automobile transportation, and the shift to other specialties, such as forestry products and climate-controlled packed goods shipping, may require significant sunk costs, such as expensive car trailers.
# * Differentiation: Entrants often struggle to differentiate from established dealerships, and must compete for relationships with suppliers, financing companies, and customers.
# * Labour Expenses: New entrants need to find skilled salespeople and mechanics, which can pose a moderate barrier to entry.
#
# These challenges are mentioned in the context under the subheading "Barriers to Entry" for the local specialized freight trucking industry in Canada.
#
# Result 22
# Question: Here is a question that can be fully answered from the given context:
#
# "Key Success Factors for Local Specialized Freight Trucking companies include developing a strong reputation, generating repeat customers, and providing superior after-sales service. What is the primary way in which successful Local Specialized Freight Trucking businesses handle concentration in the market?"
#
# This question requires the reader to understand the key success factors mentioned in the context and how they relate to the topic of Local Specialized Freight Trucking.
# Answer: The primary way in which successful Local Specialized Freight Trucking businesses handle concentration in the market is by developing a strong reputation, generating repeat customers, and providing superior after-sales service.
# Result 23
# Question: Here is a question that can be fully answered from the given context:
#
# "Despite the importance of livestock transportation, what has increased the complexity and documentation requirements for this service in Canada?"
#
# This question can be answered by referencing the following sentence in the context:
#
# "The lack of viable alternatives causes livestock companies to depend on trucking for animal transportation. Nonetheless, stringent animal welfare regulations in Canada have increased the complexity and documentation requirements for livestock transport.
# Answer: Stringent animal welfare regulations in Canada have increased the complexity and documentation requirements for livestock transport.
#
# Result 24
# Question: Here is a question that can be fully answered from the given context:
#
# "Are regulatory barriers at both the provincial and federal levels governing the testing of autonomous vehicles in Canada?"
#
# This question is formed using the topic "Regulatory barriers in Canada" and can be answered directly from the context, which states: "Regulatory barriers at both the provincial and federal levels govern the testing of autonomous vehicles in Canada...
# Answer: Yes, regulatory barriers at both the provincial and federal levels govern the testing of autonomous vehicles in Canada.
#
# Result 25
# Question: Here is a rewritten version of the question:
#
# "What operational strategy enables Canadian Local Specialized Freight Trucking firms to thrive during market fluctuations?"
#
# I've kept the core meaning of the original question, but made it more concise and indirect by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "operational strategy" instead of "operational strategy helps")
# * Focusing on the key outcome (thriving during market fluctuations) rather than the specific practices that lead to it.
# Answer: Based on the provided context, the operational strategy that enables Canadian Local Specialized Freight Trucking firms to thrive during market fluctuations is:
#
# Maintain efficient work practices, use new technology to contain costs and boost productivity, and adapt quickly to changing regulations.
#
# This strategy is mentioned in the context as a key success factor for Local Specialized Freight Trucking firms in Canada, allowing them to overcome volatility and thrive in a competitive market.
#
# Result 26
# Question: Here is the rewritten question:
#
# "What GM crops are on the market, excluding wheat?"
#
# This question conveys the same meaning as the original, but in a more indirect and concise manner. It requires the reader to make the same logical connections and inferences as the original question, but in a more subtle way.
# Answer: According to the context, genetically modified (GM) crops that are on the market, excluding wheat, include:
#
# * Corn (specifically, GM corn seeds that offer enhanced resistance to pests and diseases, safeguarding crops, and provide increased yield potential)
# * Soybeans
# * Cotton
#
# Result 27
# Question: Here is a rewritten version of the question:
#
# "When did Canada's Auto Parts Mfg. industry see a big revenue boost?"
#
# I've used abbreviations (e.g. "Mfg." for "Manufacturing") and shortened the question to make it more concise while still conveying the same meaning.
# Answer: According to the provided context, Canada's Auto Parts Mfg. industry saw a big revenue boost in 2024, with a 1.9% jump in revenue and a profit margin of 8.7%.
#
# Result 28
# Question: Here is the rewritten question:
#
# "What kind of freight do Canadian local trucking companies haul for ag products?"
#
# I shortened the question by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "ag" for "agricultural")
# * Simplifying the sentence structure
# * Focusing on the main idea of the question
# Answer: According to the provided context, Canadian local trucking companies haul the following types of freight for ag products:
#
# * Local agricultural products trucking
# * Local bulk liquid trucking
# * Local dump trucking and flatbed trucking
# * Local refrigerated products trucking
#
# Result 29
# Question: How much of Canada's wheat demand comes from imports?
# Answer: According to the context, imports account for a minimal share of domestic demand, typically less than 2.0% of domestic demand in a given year.
#
# Result 30
# Question: Here is a rewritten version of the question:
#
# "What advantage do buyers gain when comparing freight trucking companies in Canada?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "freight trucking" instead of "long-distance freight trucking")
# * Focusing on the key benefit for buyers, rather than the process of comparison.
# Answer: According to the context, buyers gain the advantage of being able to "measure service quality by the frequency of service and capacity" when comparing freight trucking companies in Canada. This allows buyers to easily compare freight trucking companies and choose the most reliable businesses for transport.
#
# Result 31
# Question: Here is a rewritten version of the question:
#
# "What crop helps farmers manage market risks?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "crop" instead of "type of crop")
# * Focusing on the key aspect of the question (managing market risks) rather than the specific benefit (diversifying output and combating revenue volatility)
# Answer: Based on the provided context, the answer to the rewritten question is:
#
# Corn
#
# According to the context, growing premium, disease-resistant corn varieties reduces the impact of disease outbreaks and adverse weather, stabilizing yields and lessening volatility. This approach helps farmers manage market risks by ensuring more consistent production, which helps mitigate market fluctuations.
#
# Result 32
# Question: Here is the rewritten question:
#
# "What could undermine the benefits of the company's expansion?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "the company's" becomes "the company")
# * Changing the wording to make it more concise and natural-sounding.
# Answer: Based on the provided context, I don't have enough information to determine what could undermine the benefits of the company's expansion. The context appears to be industry reports or analyses, but it doesn't specify which company or industry is being discussed.
#
# Result 33
# Question: Here is a rewritten version of the question:
#
# "What's the net change in Auto Parts Manufacturing businesses in Canada from 2024 to 2029?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Using a shorter phrase ("net change" instead of "expected annual change")
# * Removing unnecessary words and phrases
# * Using an abbreviation ("Auto Parts Manufacturing" instead of "the Auto Parts Manufacturing industry")
# * Focusing on the main idea of the question ("change in businesses") rather than the specific details.
# Answer: According to the provided context, the forecasted annual change in the number of businesses in the Auto Parts Manufacturing industry in Canada from 2024 to 2029 is 0.9%.
#
# Result 34
# Question: Here is the rewritten question:
#
# "What share of 2024 industry revenue is domestic?
# Answer: I don't know. The provided context does not include information about the share of 2024 industry revenue that is domestic.
#
# Result 35
# Question: Here's a rewritten version of the question:
#
# "What owns the rights to a Canadian car dealers report?"
#
# I've used abbreviations like "owns" instead of "retains" and "rights" to make the question shorter and more concise. I've also removed unnecessary words to make it more direct and to the point.
# Answer: Based on the provided context, it appears that IBISWorld owns the rights to the Canadian car dealers report.
#
# Result 36
# Question: Here's a rewritten version of the question:
#
# "What drives Canadian auto parts revenue growth, and how do they stay competitive with tech changes?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Using a more general term "drives" instead of "economic conditions"
# * Shortening "auto parts manufacturers" to "auto parts"
# * Using an abbreviation "tech" for "technological"
# * Removing unnecessary words and phrases to make the question more concise.
# Answer: Based on the provided context, here's an answer to the rewritten question:
#
# Canadian auto parts revenue growth is driven by strong economic conditions, stable consumer confidence, and a growing demand for new and used cars, as well as repairs on existing vehicles. The increasing average vehicle age in Canada, which is currently at 11 years, also supports demand for aftermarket parts.
#
# To stay competitive with technological changes, Canadian auto parts manufacturers must invest in research and development to improve their products and secure supply contracts with automakers and aftermarkets. They also need to invest in new technology to enhance operational efficiency and quality, which will help them differentiate from foreign competitors and reduce substitution.
#
# Additionally, manufacturers must adapt to the shift towards electric and autonomous vehicles, as well as other safety and sustainability innovations, by pivoting to new markets and developing niche products. This will enable them to create new opportunities and stay competitive in the industry.
# Result 37
# Question: Here's a rewritten version of the question:
#
# "What triggers industry growth in Canada when a key competitor lowers prices?"
#
# I've used abbreviations like "key" instead of "major" and "triggers" instead of "drives" to make the question shorter and more indirect.
# Answer: Based on the provided context, it appears that industry growth in Canada is influenced by various factors, but there is no specific information on what triggers growth when a key competitor lowers prices.
#
# However, the context does mention that severe input shortages have decimated the supply of cars, leading to higher costs and prices for consumers. This has given buyers significant pricing power, allowing them to negotiate prices with dealers.
#
# Additionally, the context mentions that technological advancements in freight trucking will remain crucial for future competitiveness, and that investments in electric and autonomous vehicles, as well as Internet of Things (IoT) integrations, will optimize logistics operations.
#
# It's also worth noting that the context mentions that the rebound in economic growth is expected to boost demand for freight transportation services, driven by increased consumer spending and construction investments.
#
# However, without more specific information, it's difficult to determine what triggers industry growth in Canada when a key competitor lowers prices.
#
# Result 38
# Question: Here's a rewritten version of the question:
#
# "What kinds of freight do Canadian long-haul carriers move?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "long-haul" instead of "operating both locally and over long distances")
# * Focusing on the key aspect of the question (the types of freight transported)
# Answer: Based on the provided context, Canadian long-haul carriers in the 48412 industry (General Freight Trucking, Long Distance) move a variety of freight, including:
#
# * Long-distance truckload transportation
# * Long-distance less-than-truckload (LTL) transportation
#
# In the 48423 industry (Specialized Freight (except Used Goods) Trucking, Long Distance), Canadian long-haul carriers move specialized freight, including:
#
# * Long-distance automobile carrier trucking
# * Long-distance bulk liquid trucking
# * Long-distance agricultural products trucking (including livestock)
# * Long-distance hazardous material trucking
# * Long-distance gravel hauling services
# * Long-distance refrigerated products trucking
# * Long-distance garbage hauling
# * Long-distance tanker trucking
#
# These industries cover a range of specialized and general freight transportation services, indicating that Canadian long-haul carriers move a variety of goods, including automobiles, liquids, agricultural products, hazardous materials, and more.
#
# Result 39
# Question: Here is the rewritten question:
#
# "What year between 2024-2029 will wheat farming revenue in Canada peak before declining?
# Answer: Based on the provided context, the revenue growth rate for wheat farming in Canada is expected to be 0.8% from 2024 to 2029. This suggests that the revenue will continue to grow, albeit at a slow pace, over the next few years.
#
# However, the context also mentions that a continued gain in the world price of wheat, counteracted by flagging demand, will drag down revenue growth. This implies that the revenue growth rate may slow down or even decline in the later years of the forecast period.
#
# Given this information, it is difficult to pinpoint the exact year when the revenue will peak before declining. However, based on the provided data, the revenue growth rate is expected to be 0.8% from 2024 to 2029, which suggests that the revenue may continue to grow, albeit at a slow pace, over the next few years.
#
# Therefore, I would say that I don't know the exact year when the revenue will peak before declining, but it is likely to be in the earlier years of the forecast period, such as 2025 or 2026.
#
# Result 40
# Question: Here's a rewritten version of the question:
#
# "What Canadian industries are easiest for specialized trucking companies to operate in?"
#
# I've kept the core meaning of the original question, but made it more concise and indirect by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "operating in" instead of "profit recovery efforts face the least resistance due to favorable market conditions and structural advantages")
# * Changing the wording to make it more conversational and less formal.
# Answer: Based on the provided context, it appears that the Canadian industry with the most favorable conditions for specialized trucking companies is the nonresidential construction industry. This is due to the expected rebound in demand for trucking services as the Canadian economy recovers, driven by monetary easing and increased industrial output.
#
# Additionally, the industry's characteristics, such as low customer class concentration and low product/service concentration, make it easier for specialized trucking companies to operate. The industry's low revenue volatility and moderate assistance level also contribute to a more stable environment for trucking companies.
#
# However, it's essential to note that the industry's performance is also influenced by external factors, such as the high interest rates imposed by the Bank of Canada, which have made investing in expansion and new construction projects difficult, cutting into dry bulk freight volumes.
#
# Therefore, while the nonresidential construction industry may be a relatively favorable environment for specialized trucking companies, it's not without its challenges.
#
# Result 41
# Question: Here's a rewritten version of the question:
#
# "What quartile has the strongest link between asset leverage and ROA?"
#
# This version conveys the same meaning as the original question but in a more indirect and concise way, using abbreviations like "ROA" (Return on Assets) and "asset leverage" to refer to the ratio of total assets to equity.
# Answer: To answer your question, I'll need to analyze the data provided.
#
# The ratio of total assets to equity is calculated as Total Assets / Total Equity. I'll calculate this ratio for each industry and year, and then compare it to the Return on Assets (ROA) ratio.
#
# Here are the results:
#
# 1. Wheat Farming in Canada:
# 	* 2018: 2,012.4 / 1,012.4 = 2.0 (Total Assets) / 1,012.4 (Total Equity) = 1.98 (Asset Leverage) vs. -3.8% ROA
# 	* 2019: 2,139.5 / 1,139.5 = 1.88 vs. 1.1% ROA
# 	* 2020: 2,673.0 / 1,673.0 = 1.60 vs. -0.5% ROA
# 	* 2021: 2,905.3 / 1,905.3 = 1.53 vs. 2.5% ROA
# 	* 2022: 3,151.4 / 1,151.4 = 2.74 vs.
#
# Result 42
# Question: Here's a rewritten version of the question:
#
# "What market conditions favor stable market share concentration for family-owned farms in Canada's corn industry?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "market conditions" instead of "market conditions do")
# * Focusing on the key aspect of the question (stable market share concentration)
# Answer: Based on the provided context, the market conditions that favor stable market share concentration for family-owned farms in Canada's corn industry are:
#
# * A decentralized industry structure, where small companies and family-owned farms operate locally and focus on niche market segments.
# * Geographical diversity, which disperses production geographically and prevents dominance by a few large players.
# * Regional crop rotation and environmental conditions, which necessitate diverse farming approaches and reduce the likelihood of market concentration.
#
# These conditions contribute to a low-concentration market, where competition is more dispersed, and family-owned farms can maintain a stable market share.
#
# Result 43
# Question: Here is the rewritten question:
#
# "What holds back live animal transport growth?
# Answer: Regulatory oversight over the conditions of livestock transport is limiting the growth of the segment. Specifically, regulations prohibit transporting livestock for more than 36 hours without food, water, or rest, and compromised cattle can only be transported for a maximum of 12 hours.
#
# CPU times: user 1.99 s, sys: 76.4 ms, total: 2.07 s
# Wall time: 2min 26s

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %% [markdown]
# #### Preview the final test set

# %%
dataset.to_pandas()
# Out:
#                                              question  \
# 0   Here is a question that can be fully answered ...
# 1   Here is a question that can be fully answered ...
# 2   Here is a question that can be fully answered ...
# 3   Here is a question that can be fully answered ...
# 4   Here is a question that can be fully answered ...
# 5   Here is a question that can be fully answered ...
# 6   Here is a question that can be fully answered ...
# 7   Here is a question that can be fully answered ...
# 8   Here is a question that can be fully answered ...
# 9   Here is a question that can be fully answered ...
# 10  Here is a question that can be fully answered ...
# 11  Here is a question that can be fully answered ...
# 12  Here is a question that can be fully answered ...
# 13  Here is a question that can be fully answered ...
# 14  Here is a question that can be fully answered ...
# 15  Here is a question that can be fully answered ...
# 16  Here is a question that can be fully answered ...
# 17  Here is a question that can be fully answered ...
# 18  Here is a question that can be fully answered ...
# 19  Here is a question that can be fully answered ...
# 20  Here is a question that can be fully answered ...
# 21  Here is a question that can be fully answered ...
# 22  Here is a question that can be fully answered ...
# 23  Here is a question that can be fully answered ...
# 24  Here is a question that can be fully answered ...
# 25  Here is a rewritten version of the question:\n...
# 26  Here is the rewritten question:\n\n"What GM cr...
# 27  Here is a rewritten version of the question:\n...
# 28  Here is the rewritten question:\n\n"What kind ...
# 29  How much of Canada's wheat demand comes from i...
# 30  Here is a rewritten version of the question:\n...
# 31  Here is a rewritten version of the question:\n...
# 32  Here is the rewritten question:\n\n"What could...
# 33  Here is a rewritten version of the question:\n...
# 34  Here is the rewritten question:\n\n"What share...
# 35  Here's a rewritten version of the question:\n\...
# 36  Here's a rewritten version of the question:\n\...
# 37  Here's a rewritten version of the question:\n\...
# 38  Here's a rewritten version of the question:\n\...
# 39  Here is the rewritten question:\n\n"What year ...
# 40  Here's a rewritten version of the question:\n\...
# 41  Here's a rewritten version of the question:\n\...
# 42  Here's a rewritten version of the question:\n\...
# 43  Here is the rewritten question:\n\n"What holds...
#
#                                              contexts  \
# 0   [ers benefit both parties and will remain popu...
# 1   [ navigate economic downturns and invest in ne...
# 2   [ Ireland\nâ¢\nFreight Trucking in China\nLon...
# 3   [.8 pp\nProfit per Business\n$69,567\nCurrent ...
# 4   [.8 1.9 2.6 1.6 3.2 2.8 2.5\nLabor intensive C...
# 5   [ Columbia\n43 11.3 886.4 11.2 40.9 4.0 1,885 ...
# 6   [ landscape is much more demanding than for tr...
# 7   [ landscape is much more demanding than for tr...
# 8   [Transportation and Warehousing In Canada â¢ ...
# 9   [ who don't enjoy the same pricing power.\nâ¢...
# 10  [.8m\nExports High Increasing\nWhat are the in...
# 11  [ navigate economic downturns and invest in ne...
# 12  [s Low Revenue Growth (2005-2024)\nLow Outlier...
# 13  [ 2028\n0\n50\n100\n150\nSource: IBISWorld\nCo...
# 14  [154 14.5 1.0 33.7\n2026 275,063 0.5 1.7 1.7 4...
# 15  [ essential. These contacts can lead to partne...
# 16  [154 14.5 1.0 33.7\n2026 275,063 0.5 1.7 1.7 4...
# 17  [ who don't enjoy the same pricing power.\nâ¢...
# 18  [.\nForecasted\nAnnual Revenue ($bn) Change (%...
# 19  [ing companies despite economic volatility. As...
# 20  [Building strong ties with suppliers ensures a...
# 21  [ market. More prominent companies will target...
# 22  [ market. More prominent companies will target...
# 23  [ers benefit both parties and will remain popu...
# 24  [ from manufacturers to wholesalers and often ...
# 25  [.8 18,759 18,232 39,394 2,680.4\n2028 11,837....
# 26  [ available\nâ¢\nGenetically modified crops l...
# 27  [9 2,855.5 18,081.5 1,041.7\n2016 9,346.4 1,76...
# 28  [Transportation and Warehousing In Canada â¢ ...
# 29  [ available\nâ¢\nGenetically modified crops l...
# 30  [ fuel surcharges, can help long-distance frei...
# 31  [123.2 9,970 9,092 44,993 12,126.2 33.3 741.8\...
# 32  [ its own expectations amid economic uncertain...
# 33  [shot\nRevenue Total value ($) and annual chan...
# 34  [ Still, the long-truck segment doesn't transi...
# 35  [ you find the industry information you need -...
# 36  [\nî¬¤ Industry Structure Characteristic Level...
# 37  [,194 â18-â23 î¤¾0.2 %\nâ23-â28 î¥0.1...
# 38  [Transportation and Warehousing In Canada â¢ ...
# 39  [itive\nAt a Glance\nRevenue\n$16.1bn â19-â...
# 40  [ who don't enjoy the same pricing power.\nâ¢...
# 41  [)\n38.8 43.0 44.2 50.8 54.3 40.0 43.8 48.3 59...
# 42  [ possible based on changes in yields, weather...
# 43  [ from manufacturers to wholesalers and often ...
#
#                                          ground_truth evolution_type  \
# 0   Construction activity drives the demand for dr...         simple
# 1   The government's pro-immigration policies are ...         simple
# 2   The rebound in economic growth is expected to ...         simple
# 3   The growth of e-commerce in the long-distance ...         simple
# 4   The answer to given question is not present in...         simple
# 5   Ontario has the majority of new car dealership...         simple
# 6   Successful businesses in the specialized truck...         simple
# 7   Successful businesses in the specialized truck...         simple
# 8   IBISWorld specializes in industry research wit...         simple
# 9   The expected long-term effects of rising truck...         simple
# 10  Ireland, the US, and the United Kingdom are ke...         simple
# 11                                                nan         simple
# 12  The answer to given question is present in con...         simple
# 13                                               100%         simple
# 14  The answer to given question is present in con...         simple
# 15  Establishing a strong market presence in the l...         simple
# 16  The average annual percentage change in the nu...         simple
# 17  Fuel costs and pricing power affect the profit...         simple
# 18  The answer to given question is not present in...         simple
# 19  The rebound in economic growth is expected to ...         simple
# 20  Low barriers to entry promote a fiercely compe...         simple
# 21  Potential industry entrants face challenges in...         simple
# 22  Developing a strong reputation is the primary ...         simple
# 23  Stringent animal welfare regulations in Canada...         simple
# 24  Yes, regulatory barriers at both the provincia...         simple
# 25  The answer to given question is not present in...      reasoning
# 26  Genetically modified crops like corn, soybeans...      reasoning
# 27  The answer to given question is not present in...      reasoning
# 28  Canadian local trucking companies haul local a...      reasoning
# 29  Imports account for a minimal share of domesti...      reasoning
# 30  Buyers can measure service quality by the freq...      reasoning
# 31  Diversifying output between wheat and other ty...      reasoning
# 32  The answer to given question is not present in...      reasoning
# 33  The answer to given question is not present in...      reasoning
# 34  The answer to given question is present in con...      reasoning
# 35  The answer to given question is not present in...  multi_context
# 36  Canadian auto parts revenue growth is driven b...  multi_context
# 37  Trade developments drive industry growth in Ca...  multi_context
# 38  Canadian long-haul carriers move bulk liquids,...  multi_context
# 39  The answer to given question is not present in...  multi_context
# 40  Local specialized freight trucking in Canada i...  multi_context
# 41  The answer to given question is not present in...  multi_context
# 42  Geographical diversity and the industry's dece...  multi_context
# 43  Regulations and oversight over the conditions ...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 1   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 2   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 3   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 4   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 5   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 6   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 7   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 8   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 9   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 10  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 11  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 12  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 13  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 14  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 15  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 16  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 17  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 18  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 19  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 20  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 21  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 22  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 23  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 24  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 25  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 26  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 27  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 28  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 29  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 30  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 31  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 32  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 33  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 34  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 35  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 36  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 37  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 38  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 39  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 40  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 41  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 42  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 43  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
#
#                                                answer
# 0   The demand for dry bulk transportation in the ...
# 1   The expected outcomes of the government's pro-...
# 2   The rebound in economic growth is expected to ...
# 3   According to the context, the growth of e-comm...
# 4   To calculate the average debt ratio of corn fa...
# 5   The province in Canada with the majority of ne...
# 6   According to the context, the key factors that...
# 7   According to the context, the key factors that...
# 8   IBISWorld specializes in industry research wit...
# 9   According to the context, the expected long-te...
# 10  The key international markets that drive deman...
# 11  Based on the provided context, the expected tr...
# 12  The expected Compound Annual Growth Rate (CAGR...
# 13  According to the Electric Vehicle Availability...
# 14  The question cannot be answered from the given...
# 15  According to the context, establishing a stron...
# 16  Unfortunately, the context provided does not i...
# 17  Fuel costs and pricing power have a significan...
# 18  The forecasted revenue growth rate for the Lon...
# 19  The rebound in economic growth is expected to ...
# 20  Low barriers to entry in the long-distance fre...
# 21  According to the context, potential industry e...
# 22  The primary way in which successful Local Spec...
# 23  Stringent animal welfare regulations in Canada...
# 24  Yes, regulatory barriers at both the provincia...
# 25  Based on the provided context, the operational...
# 26  According to the context, genetically modified...
# 27  According to the provided context, Canada's Au...
# 28  According to the provided context, Canadian lo...
# 29  According to the context, imports account for ...
# 30  According to the context, buyers gain the adva...
# 31  Based on the provided context, the answer to t...
# 32  Based on the provided context, I don't have en...
# 33  According to the provided context, the forecas...
# 34  I don't know. The provided context does not in...
# 35  Based on the provided context, it appears that...
# 36  Based on the provided context, here's an answe...
# 37  Based on the provided context, it appears that...
# 38  Based on the provided context, Canadian long-h...
# 39  Based on the provided context, the revenue gro...
# 40  Based on the provided context, it appears that...
# 41  To answer your question, I'll need to analyze ...
# 42  Based on the provided context, the market cond...
# 43  Regulatory oversight over the conditions of li...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - *[Faithfulness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/faithfulness.html)*: Are all the claims that are made in the answer inferred from the given context(s)?
# - *[Context Precision](https://docs.ragas.io/en/v0.1.21/concepts/metrics/context_precision.html)*: Did our retriever return good results that matched the question it was being asked?
# - *[Answer Correctness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/answer_correctness.html)*: Was the generated answer correct? Was it complete?

# %%
# %%time
score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/132 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# CPU times: user 9.56 s, sys: 374 ms, total: 9.94 s
# Wall time: 2min 12s
#                                              question  \
# 0   Here is a question that can be fully answered ...
# 1   Here is a question that can be fully answered ...
# 2   Here is a question that can be fully answered ...
# 3   Here is a question that can be fully answered ...
# 4   Here is a question that can be fully answered ...
# 5   Here is a question that can be fully answered ...
# 6   Here is a question that can be fully answered ...
# 7   Here is a question that can be fully answered ...
# 8   Here is a question that can be fully answered ...
# 9   Here is a question that can be fully answered ...
# 10  Here is a question that can be fully answered ...
# 11  Here is a question that can be fully answered ...
# 12  Here is a question that can be fully answered ...
# 13  Here is a question that can be fully answered ...
# 14  Here is a question that can be fully answered ...
# 15  Here is a question that can be fully answered ...
# 16  Here is a question that can be fully answered ...
# 17  Here is a question that can be fully answered ...
# 18  Here is a question that can be fully answered ...
# 19  Here is a question that can be fully answered ...
# 20  Here is a question that can be fully answered ...
# 21  Here is a question that can be fully answered ...
# 22  Here is a question that can be fully answered ...
# 23  Here is a question that can be fully answered ...
# 24  Here is a question that can be fully answered ...
# 25  Here is a rewritten version of the question:\n...
# 26  Here is the rewritten question:\n\n"What GM cr...
# 27  Here is a rewritten version of the question:\n...
# 28  Here is the rewritten question:\n\n"What kind ...
# 29  How much of Canada's wheat demand comes from i...
# 30  Here is a rewritten version of the question:\n...
# 31  Here is a rewritten version of the question:\n...
# 32  Here is the rewritten question:\n\n"What could...
# 33  Here is a rewritten version of the question:\n...
# 34  Here is the rewritten question:\n\n"What share...
# 35  Here's a rewritten version of the question:\n\...
# 36  Here's a rewritten version of the question:\n\...
# 37  Here's a rewritten version of the question:\n\...
# 38  Here's a rewritten version of the question:\n\...
# 39  Here is the rewritten question:\n\n"What year ...
# 40  Here's a rewritten version of the question:\n\...
# 41  Here's a rewritten version of the question:\n\...
# 42  Here's a rewritten version of the question:\n\...
# 43  Here is the rewritten question:\n\n"What holds...
#
#                                              contexts  \
# 0   [ers benefit both parties and will remain popu...
# 1   [ navigate economic downturns and invest in ne...
# 2   [ Ireland\nâ¢\nFreight Trucking in China\nLon...
# 3   [.8 pp\nProfit per Business\n$69,567\nCurrent ...
# 4   [.8 1.9 2.6 1.6 3.2 2.8 2.5\nLabor intensive C...
# 5   [ Columbia\n43 11.3 886.4 11.2 40.9 4.0 1,885 ...
# 6   [ landscape is much more demanding than for tr...
# 7   [ landscape is much more demanding than for tr...
# 8   [Transportation and Warehousing In Canada â¢ ...
# 9   [ who don't enjoy the same pricing power.\nâ¢...
# 10  [.8m\nExports High Increasing\nWhat are the in...
# 11  [ navigate economic downturns and invest in ne...
# 12  [s Low Revenue Growth (2005-2024)\nLow Outlier...
# 13  [ 2028\n0\n50\n100\n150\nSource: IBISWorld\nCo...
# 14  [154 14.5 1.0 33.7\n2026 275,063 0.5 1.7 1.7 4...
# 15  [ essential. These contacts can lead to partne...
# 16  [154 14.5 1.0 33.7\n2026 275,063 0.5 1.7 1.7 4...
# 17  [ who don't enjoy the same pricing power.\nâ¢...
# 18  [.\nForecasted\nAnnual Revenue ($bn) Change (%...
# 19  [ing companies despite economic volatility. As...
# 20  [Building strong ties with suppliers ensures a...
# 21  [ market. More prominent companies will target...
# 22  [ market. More prominent companies will target...
# 23  [ers benefit both parties and will remain popu...
# 24  [ from manufacturers to wholesalers and often ...
# 25  [.8 18,759 18,232 39,394 2,680.4\n2028 11,837....
# 26  [ available\nâ¢\nGenetically modified crops l...
# 27  [9 2,855.5 18,081.5 1,041.7\n2016 9,346.4 1,76...
# 28  [Transportation and Warehousing In Canada â¢ ...
# 29  [ available\nâ¢\nGenetically modified crops l...
# 30  [ fuel surcharges, can help long-distance frei...
# 31  [123.2 9,970 9,092 44,993 12,126.2 33.3 741.8\...
# 32  [ its own expectations amid economic uncertain...
# 33  [shot\nRevenue Total value ($) and annual chan...
# 34  [ Still, the long-truck segment doesn't transi...
# 35  [ you find the industry information you need -...
# 36  [\nî¬¤ Industry Structure Characteristic Level...
# 37  [,194 â18-â23 î¤¾0.2 %\nâ23-â28 î¥0.1...
# 38  [Transportation and Warehousing In Canada â¢ ...
# 39  [itive\nAt a Glance\nRevenue\n$16.1bn â19-â...
# 40  [ who don't enjoy the same pricing power.\nâ¢...
# 41  [)\n38.8 43.0 44.2 50.8 54.3 40.0 43.8 48.3 59...
# 42  [ possible based on changes in yields, weather...
# 43  [ from manufacturers to wholesalers and often ...
#
#                                          ground_truth evolution_type  \
# 0   Construction activity drives the demand for dr...         simple
# 1   The government's pro-immigration policies are ...         simple
# 2   The rebound in economic growth is expected to ...         simple
# 3   The growth of e-commerce in the long-distance ...         simple
# 4   The answer to given question is not present in...         simple
# 5   Ontario has the majority of new car dealership...         simple
# 6   Successful businesses in the specialized truck...         simple
# 7   Successful businesses in the specialized truck...         simple
# 8   IBISWorld specializes in industry research wit...         simple
# 9   The expected long-term effects of rising truck...         simple
# 10  Ireland, the US, and the United Kingdom are ke...         simple
# 11                                                nan         simple
# 12  The answer to given question is present in con...         simple
# 13                                               100%         simple
# 14  The answer to given question is present in con...         simple
# 15  Establishing a strong market presence in the l...         simple
# 16  The average annual percentage change in the nu...         simple
# 17  Fuel costs and pricing power affect the profit...         simple
# 18  The answer to given question is not present in...         simple
# 19  The rebound in economic growth is expected to ...         simple
# 20  Low barriers to entry promote a fiercely compe...         simple
# 21  Potential industry entrants face challenges in...         simple
# 22  Developing a strong reputation is the primary ...         simple
# 23  Stringent animal welfare regulations in Canada...         simple
# 24  Yes, regulatory barriers at both the provincia...         simple
# 25  The answer to given question is not present in...      reasoning
# 26  Genetically modified crops like corn, soybeans...      reasoning
# 27  The answer to given question is not present in...      reasoning
# 28  Canadian local trucking companies haul local a...      reasoning
# 29  Imports account for a minimal share of domesti...      reasoning
# 30  Buyers can measure service quality by the freq...      reasoning
# 31  Diversifying output between wheat and other ty...      reasoning
# 32  The answer to given question is not present in...      reasoning
# 33  The answer to given question is not present in...      reasoning
# 34  The answer to given question is present in con...      reasoning
# 35  The answer to given question is not present in...  multi_context
# 36  Canadian auto parts revenue growth is driven b...  multi_context
# 37  Trade developments drive industry growth in Ca...  multi_context
# 38  Canadian long-haul carriers move bulk liquids,...  multi_context
# 39  The answer to given question is not present in...  multi_context
# 40  Local specialized freight trucking in Canada i...  multi_context
# 41  The answer to given question is not present in...  multi_context
# 42  Geographical diversity and the industry's dece...  multi_context
# 43  Regulations and oversight over the conditions ...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 1   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 2   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 3   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 4   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 5   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 6   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 7   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 8   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 9   [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 10  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 11  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 12  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 13  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 14  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 15  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 16  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 17  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 18  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 19  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 20  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 21  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 22  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 23  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 24  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 25  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 26  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 27  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 28  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 29  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 30  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 31  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 32  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 33  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 34  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 35  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 36  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 37  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 38  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 39  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 40  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 41  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 42  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
# 43  [{'source': '/projects/RAG2/scotia-2/Datasets-...          True
#
#                                                answer  faithfulness  \
# 0   The demand for dry bulk transportation in the ...      1.000000
# 1   The expected outcomes of the government's pro-...           NaN
# 2   The rebound in economic growth is expected to ...           NaN
# 3   According to the context, the growth of e-comm...           NaN
# 4   To calculate the average debt ratio of corn fa...      0.666667
# 5   The province in Canada with the majority of ne...      1.000000
# 6   According to the context, the key factors that...           NaN
# 7   According to the context, the key factors that...           NaN
# 8   IBISWorld specializes in industry research wit...      1.000000
# 9   According to the context, the expected long-te...           NaN
# 10  The key international markets that drive deman...      1.000000
# 11  Based on the provided context, the expected tr...           NaN
# 12  The expected Compound Annual Growth Rate (CAGR...      1.000000
# 13  According to the Electric Vehicle Availability...      1.000000
# 14  The question cannot be answered from the given...      0.333333
# 15  According to the context, establishing a stron...           NaN
# 16  Unfortunately, the context provided does not i...           NaN
# 17  Fuel costs and pricing power have a significan...           NaN
# 18  The forecasted revenue growth rate for the Lon...      1.000000
# 19  The rebound in economic growth is expected to ...           NaN
# 20  Low barriers to entry in the long-distance fre...           NaN
# 21  According to the context, potential industry e...           NaN
# 22  The primary way in which successful Local Spec...      1.000000
# 23  Stringent animal welfare regulations in Canada...      1.000000
# 24  Yes, regulatory barriers at both the provincia...      0.500000
# 25  Based on the provided context, the operational...           NaN
# 26  According to the context, genetically modified...      1.000000
# 27  According to the provided context, Canada's Au...      0.000000
# 28  According to the provided context, Canadian lo...           NaN
# 29  According to the context, imports account for ...      1.000000
# 30  According to the context, buyers gain the adva...      1.000000
# 31  Based on the provided context, the answer to t...           NaN
# 32  Based on the provided context, I don't have en...           NaN
# 33  According to the provided context, the forecas...      1.000000
# 34  I don't know. The provided context does not in...      0.000000
# 35  Based on the provided context, it appears that...      0.500000
# 36  Based on the provided context, here's an answe...           NaN
# 37  Based on the provided context, it appears that...           NaN
# 38  Based on the provided context, Canadian long-h...           NaN
# 39  Based on the provided context, the revenue gro...           NaN
# 40  Based on the provided context, it appears that...           NaN
# 41  To answer your question, I'll need to analyze ...           NaN
# 42  Based on the provided context, the market cond...           NaN
# 43  Regulatory oversight over the conditions of li...      1.000000
#
#     context_precision  answer_correctness
# 0                 1.0            0.733687
# 1                 1.0            0.651770
# 2                 1.0            0.792041
# 3                 1.0            0.895714
# 4                 0.0            0.351871
# 5                 1.0            0.537397
# 6                 1.0                 NaN
# 7                 1.0            0.781102
# 8                 1.0            0.566585
# 9                 1.0                 NaN
# 10                1.0            0.808065
# 11                1.0                 NaN
# 12                1.0            0.605791
# 13                1.0            0.657219
# 14                1.0            0.588923
# 15                1.0            0.762385
# 16                0.0                 NaN
# 17                1.0            0.482441
# 18                0.0            0.384842
# 19                1.0            0.792041
# 20                1.0                 NaN
# 21                1.0                 NaN
# 22                1.0            0.790212
# 23                1.0            1.000000
# 24                1.0            1.000000
# 25                0.0            0.107338
# 26                1.0            0.774885
# 27                0.0            0.666192
# 28                1.0            0.715140
# 29                1.0            0.841305
# 30                1.0            0.820075
# 31                1.0            0.540830
# 32                0.0            0.361940
# 33                0.0            0.356414
# 34                0.0            0.820643
# 35                0.0            0.529839
# 36                1.0            0.442387
# 37                1.0                 NaN
# 38                1.0                 NaN
# 39                0.0            0.131804
# 40                1.0            0.630621
# 41                0.0                 NaN
# 42                1.0                 NaN
# 43                1.0            0.585520

# %%
score["answer_correctness"].mean()
# Out:
# 0.6325593395188253

# %%
score["faithfulness"].mean()
# Out:
# 0.8

# %%
#"Meta-Llama-3.1-8B-Instruct"
#chunksize, answer correctness, faithfulness, number of question
#10000, 0.592, 0.698, 50
# 5000, 0.617, 0.700, 50
# 3500, 0.677, 0.734, 50
# 3000, 0.688, 0.800, 50
# 2000, 0.629, 0.742, 50
# 1000, 0.644, 0.703, 50
#  500, 0.619, 0.503, 50
#  250, 0.594, 0.527, 50

# %%
#2500, 0.63, 08
