# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://docs.ragas.io/en/stable/) (```v 0.1.22```) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [LangChain](https://python.langchain.com/docs/introduction/) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# ### <u>Requirements</u>
# 1. As you will accessing the LLMs and embedding models through Vector AI Engineering's Kaleidoscope Service (Vector Inference + Autoscaling), you will need to request a KScope API Key:
#
#       Run the following command (replace ```<user_id>``` and ```<password>```) from **within the cluster** to obtain the API Key. The ```access_token``` in the output is your KScope API Key.
#   ```bash
#   curl -X POST -d "grant_type=password" -d "username=<user_id>" -d "password=<password>" https://kscope.vectorinstitute.ai/token
#   ```
# 2. After obtaining the `.env` configurations, make sure to create the ```.kscope.env``` file in your home directory (```/h/<user_id>```) and set the following env variables:
# - For local models through Kaleidoscope (KScope):
#     ```bash
#     export OPENAI_BASE_URL="https://kscope.vectorinstitute.ai/v1"
#     export OPENAI_API_KEY=<kscope_api_key>
#     ```
# - For OpenAI models:
#    ```bash
#    export OPENAI_BASE_URL="https://api.openai.com/v1"
#    export OPENAI_API_KEY=<openai_api_key>
#    ```

# %% [markdown]
# ## Set up the RAG workflow environment

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install pdfplumber

# %%
#import pdfplumber

# %%
import numpy as np
import os
import sys

from datasets import Dataset
from pathlib import Path

from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from ragas.testset import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# #### Load config files

# %%
# Add root folder of the rag_bootcamp repo to PYTHONPATH
current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.insert(0, str(parent_dir))

# %%
from utils.load_secrets import load_env_file
load_env_file()

# %% [markdown]
# #### Set up some helper functions

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# #### Make sure other necessary items are in place

# %%
# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# #### Start by loading in the documents we'll be using to augment our RAG generations

# %%
#loader = PyPDFDirectoryLoader(documents_path)
#documents = loader.load()
#for document in documents:
#    document.metadata['file_name'] = document.metadata['source']
    
#%%time
# Load the IBIS pdfs
#directory_path = "./source_documents"
directory_path = "/projects/RAG2/scotia-2/Datasets-Scotia-2/IBIS"
loader = PyPDFDirectoryLoader(directory_path)
docs = loader.load()
print(f"Number of source documents: {len(docs)}")
for document in docs:
    document.metadata['file_name'] = document.metadata['source']
# Split the documents into smaller chunks
#text_splitter = RecursiveCharacterTextSplitter(chunk_size=3600, chunk_overlap=32)
#chunks = text_splitter.split_documents(docs)
#print(f"Number of text chunks: {len(chunks)}")
# Out:
# Number of source documents: 280

# %% [markdown]
# #### Now use OpenAI to generate a test set from the data in these documents (This takes about 2-3 minutes)

# %% [markdown]
# **IMP Note:** The LLM and embedding model used for test set generation should be more capable than the model being evaluated. Hence, we will use OpenAI GPT-4o and OpenAI embeddings for this purpose.
#
# Store your OpenAI API key in ```~/.ragas_openai.env``` using the following format (this is in addition to ```~/.kscope.env```):
#
# ```bash
# export RAGAS_OPENAI_BASE_URL="https://api.openai.com/v1"
# export RAGAS_OPENAI_API_KEY=<openai_api_key>
# ```

# %%
from utils.load_secrets import load_env_file_ragas
load_env_file_ragas()

# %%
generator_llm = ChatOpenAI(
    model="gpt-4o",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)
generator_embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)

# %%
#generator_llm = (
#    model="DeepSeek-R1-Distill-Llama-8B",
#    base_url=os.environ["OPENAI_BASE_URL"],
#    api_key=os.environ["OPENAI_API_KEY"],
#)
# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity
print(f"Setting up the RAG LLM...")
llm = ChatOpenAI(
    #model="DeepSeek-R1-Distill-Llama-8B",
    model="Meta-Llama-3.1-8B-Instruct",
    temperature=0,
    max_tokens=256,
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# Setting up the RAG LLM...

# %%
# %%time
# Create generator with OpenAI model
generator = TestsetGenerator.from_langchain(
    generator_llm=llm,
    critic_llm=llm,
    embeddings=embeddings,
)

# Generate the test set
testset = generator.generate_with_langchain_docs(
    documents=docs, 
    test_size=50,
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25},
)
# Out:
# embedding nodes:   0%|          | 0/666 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/50 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# CPU times: user 42.9 s, sys: 1.86 s, total: 44.7 s
# Wall time: 7min 20s

# %% [markdown]
# #### Preview the test dataset so far

# %%
testset1 = testset.to_pandas()

# %%
# testset1.to_parquet ('../../Testing_Data/testset_llama.parquet')
# testset1.to_csv ('../../Testing_Data/testset_llama.csv', index =False)

# %%
import joblib

# Save (serialize) the object to a file
joblib.dump(testset, "../../Testing_Data/testset_openai.pkl")
# Out:
# ['../../Testing_Data/testset_openai.pkl']

# %%
testset1.to_parquet ('../../Testing_Data/testset_openai.parquet')
testset1.to_csv ('../../Testing_Data/testset_openai.csv', index =False)

# %%
#load 
# Load (deserialize) the object from file
testset2 = joblib.load("../../Testing_Data/testset_openai.pkl")

#print(testset2)  # Output: {'name': 'Alice', 'age': 30, 'city': 'Toronto'}

# %%
print (testset==testset2)
# Out:
# True

# %% [markdown]
# ## Now, start the RAG pipeline!

# %% [markdown]
# #### Choose the RAG LLM and embedding model
# Note: This is different than the OpenAI LLM and embedding model defined above for test set generation.

# %%
RAG_LLM_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
RAG_EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# %% [markdown]
# #### Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2500, chunk_overlap=32)
chunks = text_splitter.split_documents(docs)
print(f"Number of text chunks: {len(chunks)}")
# Out:
# Number of text chunks: 397

# %%
# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name=RAG_EMBEDDING_MODEL_NAME,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# Setting up the RAG embeddings model...

# %%
# Create the vector store and the retriever
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %%
RAG_LLM_MODEL_NAME
# Out:
# 'Meta-Llama-3.1-8B-Instruct'

# %%
# %%time
# Define the RAG LLM (different than the OpenAI LLM defined above for test set generation)
print(f"Setting up the RAG LLM...")
llm = ChatOpenAI(
    model=RAG_LLM_MODEL_NAME,
    temperature=0,
    max_tokens=256,
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)
# Out:
# Setting up the RAG LLM...
# CPU times: user 18.2 ms, sys: 4.16 ms, total: 22.4 ms
# Wall time: 21.9 ms

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned. (This also takes 2-3 minutes)

# %%
# %%time
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Run the query through the RAG pipeline
    rag_pipeline = RetrievalQA.from_llm(
        llm=llm,
        retriever=retriever
    )
    answer = rag_pipeline.invoke(input=query)
    answer = answer["result"]
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
    
    # Store the result
    answers[index] = answer
# Out:
# Result 0
# Question: Here is a question that can be fully answered from the given context:
#
# "What options do buyers have in the shipping industry to ensure delivery in full and on time (DIFOT)?
# Answer: According to the context, buyers in the shipping industry have several options to ensure delivery in full and on time (DIFOT). These options include:
#
# * Shipping alternatives: Buyers can choose from various shipping alternatives, such as rail and air shipping, which provide them with multiple options to compare and select the most reliable businesses for transport.
# * Measuring service quality: Buyers can measure service quality by the frequency of service and capacity, making it relatively easy for them to compare freight trucking companies and choose the most reliable ones.
# * Multiple shipping options: The presence of many shipping alternatives within the industry and from alternative modes of transport, such as rail and air shipping, provides truckers with many sources of competition, which benefits buyers.
#
# These options enable buyers to ensure delivery in full and on time (DIFOT) by giving them the flexibility to choose the most reliable and efficient shipping options for their needs.
#
# Result 1
# Question: Here is a question that can be fully answered from the given context:
#
# question: "What is the weight limit for a light-duty vehicle?"
#
# This question can be answered directly from the context, which defines a light-duty vehicle as one weighing less than 6,350 kilograms (14,000 pounds).
# Answer: The weight limit for a light-duty vehicle is less than 6,350 kilograms (14,000 pounds).
#
# Result 2
# Question: Here is a question that can be fully answered from the given context:
#
# "Who are willing to pay a premium for organic and non-GMO corn products?"
#
# This question can be answered directly from the context, which states: "Consumer demand for organic and non-GMO corn products is rising as health-conscious customers seek alternatives that are perceived as healthier and more sustainable. Customers are often willing to pay a premium for these offerings, helping to grow revenue.
# Answer: Health-conscious customers are willing to pay a premium for organic and non-GMO corn products.
#
# Result 3
# Question: Here is a question that can be fully answered from the given context:
#
# "What effect do higher input prices have on new and used car prices?
# Answer: According to the context, higher input prices are passed on to buyers, leading to higher new and used car prices.
#
# Result 4
# Question: Here is a question that can be fully answered from the given context:
#
# "According to the IBIS World source, what percentage of industry revenue in 2024 is attributed to the human food market?
# Answer: According to the IBIS World report, the human food market (specifically, the Canadian Flour Milling industry) accounts for 484% of the Local Specialized Freight Trucking in Canada industry revenue.
#
# Result 5
# Question: Here is a question that can be fully answered from the given context:
#
# "Has the dismantling of the Canadian Wheat Board in 2012 had a positive impact on the Canadian wheat market?
# Answer: No, the context does not mention the dismantling of the Canadian Wheat Board in 2012, nor does it discuss its impact on the Canadian wheat market.
#
# Result 6
# Question: Here is a question that can be fully answered from the given context:
#
# "Will rising corn production in Canada help to limit the country's need for imports in 2023 and 2024?
# Answer: Yes, rising corn production in Canada is expected to help limit the country's need for imports in 2023 and 2024. According to the context, "Rising corn production in 2023 and 2024 will help to limit Canada's need for imports, ensuring adequate supply for domestic use."
#
# Result 7
# Question: Here is a question that can be fully answered from the given context:
#
# "According to the text, what percentage of Canada's population has access to public transportation?"
#
# This question can be answered by looking at the sentence: "Of this, approximately 70.0% have access to public transportation.
# Answer: According to the text, approximately 70.0% of Canada's population has access to public transportation.
#
# Result 8
# Question: Here is a question that can be fully answered from the given context:
#
# keyphrase: "Just-in-time inventory management"
# question: "How did the just-in-time inventory management system affect the demand for freight trucking services?
# Answer: The just-in-time (JIT) inventory management system helped freight trucking businesses as it caused manufacturers to demand more frequent shipments.
#
# Result 9
# Question: Here is a question that can be fully answered from the given context:
#
# "According to the text, what are the benefits of selecting regions with optimal natural resources for businesses?"
#
# This question can be fully answered from the context, which states that selecting regions with optimal natural resources ensures high corn yields and quality, reduces dependence on fertilizers, pesticides, irrigation, and other major expenses, and provides flexibility for farmers to expand operations and meet increasing customer demand.
# Answer: According to the text, the benefits of selecting regions with optimal natural resources for businesses are:
#
# * Ensuring high corn yields and quality
# * Reducing dependence on fertilizers, pesticides, irrigation, and other major expenses
# * Providing flexibility for farmers to expand operations and meet increasing customer demand.
#
# Result 10
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the main factors driving the shift in corn demand towards diverse and premium products?
# Answer: According to the context, the main factors driving the shift in corn demand towards diverse and premium products are:
#
# * Consumer preferences for gluten-free food options, leading to increased demand for corn as a substitute for wheat in bread and baked goods, pasta, cereals, snacks, and more.
# * Growing demand for corn in plant-based and alternative protein products, as these markets expand.
# * Rising awareness of sustainable sourcing, leading to increased demand for organic and heirloom varieties of corn, which often command higher prices.
# * Consumer interest in non-GMO and sustainably sourced options, driving demand for premium corn products.
#
# Result 11
# Question: Here is the question that can be fully answered from the given context:
#
# "What benefits do businesses gain from IBISWorld's comprehensive data analysis?
# Answer: The context does not explicitly state the benefits that businesses gain from IBISWorld's comprehensive data analysis. However, it does mention that IBISWorld helps businesses "find the industry information you need - fast." This suggests that IBISWorld's data analysis provides businesses with quick and easy access to industry information, which can be beneficial for making informed business decisions.
#
# Result 12
# Question: Here is a question that can be fully answered from the given context:
#
# "According to the outlook, what is the expected Compound Annual Growth Rate (CAGR) of revenue for the automotive industry in Canada?"
#
# This question can be answered by looking at the sentence: "Overall, revenue will expand at an expected CAGR of 3.2% to $223.6 billion through the outlook...
# Answer: According to the outlook, the expected Compound Annual Growth Rate (CAGR) of revenue for the automotive industry in Canada is 3.2%.
#
# Result 13
# Question: Here is a question that can be fully answered from the given context:
#
# "Which countries are preferred by international companies operating in Canada for importing auto parts?"
#
# This question can be answered by looking at the context, which mentions that many international companies operating in Canada often prefer to import parts from trusted suppliers in their home countries, and specifically lists Japan, Germany, and South Korea as examples of countries with extensive automotive and manufacturing sectors.
# Answer: According to the context, international companies operating in Canada often prefer to import auto parts from trusted suppliers in their home countries, and specifically, countries such as Japan, Germany, and South Korea are mentioned as examples of countries with extensive automotive and manufacturing sectors that can provide high-quality auto parts.
# Result 14
# Question: Here is a question that can be fully answered from the given context:
#
# "Who does IBISWorld industry research help with gaining insights on industries around the world?
# Answer: According to the context, IBISWorld industry research helps authorized licensees gain insights on industries around the world.
#
# Result 15
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the impact of the ongoing easing of monetary policy on the wholesale and retail markets, and how is it affecting the demand for trucking services?
# Answer: The ongoing easing of monetary policy is expected to lower borrowing costs and support a recovery in economic activity. This is expected to lead to a pickup in growth and manufacturing output, which will drive distribution services across specialized freight transport and support expansion after a muted performance between 2019 and 2024 as the industry struggled to shake off the impacts of the pandemic.
#
# The expected Consumer Annual Growth Rate (CAGR) of 1.9% in consumer spending through 2029 and the broader forecast acceleration in GDP growth from 1.1% in 2024 to 1.6% in 2025 will boost contracting services from long-distance specialized freight across all key markets.
#
# As the broader economy continues to improve and consumer spending rises, both manufacturing and retail activity are expected to climb, increasing the need for product transportation. The value of trade into and out of Canada is projected to steadily increase as its major trading partners recover from past economic challenges, driving demand for tank refrigeration truckers to transport goods to seaports and across the US borders.
#
# Result 16
# Question: Here is a question that can be fully answered from the given context:
#
# "Long-distance freight trucking in Canada is being impacted by what trend, leading businesses to contract LTL services for distribution?"
#
# This question can be answered by referencing the context, which mentions that "As merchants continue to source goods from global markets to satisfy domestic demand, many businesses are contracting long-distance LTL services for distribution, which allows them to save costs and remain competitive in the online marketplace.
# Answer: The trend impacting long-distance freight trucking in Canada is the growing demand for goods from global markets to satisfy domestic demand, leading businesses to contract long-distance LTL services for distribution.
#
# Result 17
# Question: Here is a question that can be fully answered from the given context:
#
# "Who are the major customers of auto parts manufacturers, and how do they influence the industry's markets?"
#
# This question can be answered by referencing the context, which states that "Auto part s manuf acturers rely on demand fr om aut omak ers" and that "Automak ers gener ate the majority o f revenue f or aut o part s manuf acturers".
# Answer: The major customers of auto parts manufacturers are automakers, who generate the majority of revenue for auto parts manufacturers. Automakers influence the industry's markets by relying on auto parts manufacturers for their products, and by having long-term supply contracts with multiple parts producers. This allows automakers to have a significant say in the industry's markets and can impact the demand for auto parts.
#
# Result 18
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the main challenges faced by wheat farmers due to their relatively thin profit margin?
# Answer: According to the context, the main challenges faced by wheat farmers due to their relatively thin profit margin are:
#
# 1. Rising costs: Wheat farmers have to contend with a relatively thin profit margin, and rising costs have forced them to be especially focused on limiting expenses to keep their own prices competitive.
# 2. Volatile fertilizer prices: Volatile fertilizer prices have limited profit growth, as fertilizer is a widely used component in agriculture.
# 3. Growth in purchase costs: Growth in purchase costs, including seeds and supplies, has been a major concern for wheat farmers in recent years.
#
# These challenges make it difficult for wheat farmers to maintain a stable profit margin, and they have to be constantly focused on managing their expenses and costs to remain competitive.
#
# Result 19
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the main factors that challenge profit stability in the corn farming industry?
# Answer: The main factors that challenge profit stability in the corn farming industry are:
#
# 1. Volatile corn prices, driven by changing demand from ethanol producers and other sectors, which can lead to temporary price increases that are followed by subsequent declines and competitive pressures from international producers.
# 2. Fluctuating demand for corn, particularly from ethanol producers, which can create inconsistent prices and affect farmers' profits.
# 3. Rising purchase costs, including the growing control of the seed market by Bayer, which will give it strong pricing authority, and the rising price of fertilizer.
# 4. Technological advancements that drive up depreciation costs in corn farming, including investments in advanced machinery and the implementation of modernized infrastructure that requires frequent upgrades.
# 5. Weather-related factors, such as plagues, droughts, and severe weather phenomena, which can greatly disrupt yields, reduce supply, and raise prices both domestically and globally.
# 6. Market price fluctuations in corn and competing grains, which can create market instability and make it difficult for farmers to predict revenue.
#
# These factors contribute to the high volatility in the corn farming industry, making it challenging for farmers to maintain profit stability.
#
# Result 20
# Question: Here is a question that can be fully answered from the given context:
#
# "What role do natural resources play in the manufacturing sector in Canada?
# Answer: According to the context, natural resources play a significant role in the manufacturing sector in Canada, particularly in the province of Alberta. Alberta's wealth of natural resources, such as metals and petroleum, is essential for manufacturing auto parts, and this local supply lowers production costs and enhances efficiency for manufacturers. Additionally, Alberta's natural resources drive demand for specialized trucking services, including liquid and dry bulk transportation.
#
# Result 21
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the benefit of investing in research and development for Canadian auto parts manufacturers?"
#
# This question is formed using the topic "Investing in R&D" and can be fully answered from the context, which states that "Strong R&D will help companies compete with imports" and that "Canadian auto parts manufacturers must invest in research and development to improve their products and secure supply contracts with automakers and aftermarkets.
# Answer: The benefit of investing in research and development for Canadian auto parts manufacturers is that it will help companies compete with imports and improve their products, ultimately securing supply contracts with automakers and aftermarkets.
#
# Result 22
# Question: Here is a question that can be fully answered from the given context:
#
# "What are the challenges faced by non-employer truckers in managing labor costs?"
#
# This question is formed using the topic "Labor costs and management" and can be answered by referencing the context, specifically the section that mentions "Labour costs are more difficult to manage for non-employers because owner-operators can only increase operating capacity and meet elevated demand by working longer hours or charging higher prices.
# Answer: According to the context, the challenges faced by non-employer truckers in managing labor costs are:
#
# * They can only increase operating capacity and meet elevated demand by working longer hours.
# * They can only increase operating capacity and meet elevated demand by charging higher prices.
#
# This is mentioned in the context under the section "Labor costs and management".
#
# Result 23
# Question: Here is a question that can be fully answered from the given context:
#
# "What is the benefit of using efficient manufacturing technologies for successful auto parts manufacturers?"
#
# This question is formed using the topic "Efficient manufacturing technologies" and can be answered by referencing the context, which states that successful auto parts manufacturers will use the most efficient manufacturing technologies to streamline production, reduce costs, and create greater value than competitors.
# Answer: According to the context, the benefit of using efficient manufacturing technologies for successful auto parts manufacturers is that it will help them overcome substitutes and import competition, and differentiate themselves from foreign competitors, reducing substitution.
# Result 24
# Question: Here is a question that can be fully answered from the given context:
#
# "What are some factors that have complicated the economic landscape for the trucking industry?"
#
# This question can be answered by referencing the context, which mentions "economic volatility fueled by inflationary pressures, tightened monetary policy and rising fuel costs" as factors that have complicated the landscape, particularly for long-distance trucking companies.
# Answer: According to the context, some factors that have complicated the economic landscape for the trucking industry include:
#
# * Economic volatility, which affects the volumes of distributed freight
# * Volatility in downstream markets, which translates to contract fluctuations
# * Fuel price fluctuations, which have a more pronounced impact on long-distance trucking operations due to the length of haul
# * Rising fuel costs, which are often passed down to consumers through fuel surcharges
# * Driver shortages, which continue to threaten operations and lead to declining revenue per employee
# * Changes in commodity prices, which affect demand for freight trucking and revenue for companies that rely on extracting and transporting commodities
# * Shifts in macroeconomic factors, such as consumer spending, which can lead to changes in production capacities and lower freight volumes and revenue for local specialized freight truckers.
#
# Result 25
# Question: Here is the rewritten question:
#
# "Where is NewRoads Automotive Group expanding to?"
#
# I shortened the question by removing unnecessary words and using abbreviations, while still conveying the same meaning as the original question.
# Answer: According to the context, NewRoads Automotive Group is expanding to across York Region.
#
# Result 26
# Question: Here is a rewritten version of the question:
#
# "What motivates Canadian corn farmers to choose organic crops?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using a more general term ("motivates" instead of "drives demand")
# * Focusing on the key issue ("choosing organic crops") rather than the broader context
# Answer: Based on the provided context, it appears that Canadian corn farmers are motivated to choose organic crops due to consumer demand for non-GMO and sustainably sourced products. The context mentions that "Organic and heirloom varieties of corn, which often command higher prices, will also attract consumers interested in non-GMO and sustainably sourced options." This suggests that farmers may choose to grow organic crops in order to meet the growing demand for these types of products and capitalize on the premium prices they command.
#
# Result 27
# Question: Here is a rewritten version of the question:
#
# "What operational benefits come from in-house logistics for wholesalers and manufacturers?"
#
# I've kept the core meaning of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "in-house" instead of "linking in-house")
# * Focusing on the key benefit (operational advantage) rather than the specific strategy (linking in-house logistics services)
# Answer: According to the context, in-house logistics for wholesalers and manufacturers provides the operational benefit of:
#
# * Access to capital and expanding operations, enabling them to develop in-house logistics services.
# * Reduced reliance on outsourcing distribution to third-party logistics providers and specialized trucking services, including tankers and reefers.
# * Easier development of internal fleets when transporting general freight, due to less pronounced regulatory oversight over the sector.
#
# Result 28
# Question: Here is the rewritten question:
#
# "What's the forecast for Retail Trade employee growth in Canada from 2024 to 2029?
# Answer: I don't know. The provided context does not include information about the forecast for Retail Trade employee growth in Canada from 2024 to 2029.
#
# Result 29
# Question: How does IoT-driven route optimization affect logistics pricing?
# Answer: I don't know. The provided context does not mention IoT-driven route optimization and its impact on logistics pricing.
#
# Result 30
# Question: Here is the rewritten question:
#
# "What law ties Canada's grain quality system to its legislative framework?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "ties" instead of "linking")
# * Focusing on the key elements of the question (law, grain quality system, legislative framework)
# Answer: According to the context, the law that ties Canada's grain quality system to its legislative framework is the Canada Grain Act.
#
# Result 31
# Question: Here is a rewritten version of the question:
#
# "What liability does IBIS World disclaim for misuse of their publication?"
#
# I've kept the core of the original question, but made it more concise and indirect by:
#
# * Removing the phrase "If a licensee uses the publication beyond the terms of their agreement with IBIS World", which is implied by the context
# * Using the abbreviation "misuse" to refer to using the publication beyond the terms of the agreement
# * Focusing on the specific aspect of the disclaimer (liability) rather than the broader context.
# Answer: According to the disclaimer, to the extent permitted by law, IBIS World disclaims all liability for loss or damage, direct and indirect, suffered or incurred by any person resulting from the use of, or reliance upon, the data in this publication.
#
# Result 32
# Question: How much of the industry's imports is due to the net importer deficit?
# Answer: Based on the context, I can see that the industry's imports and exports are shown in the following table:
#
# Concentration of imports and exports from each country based on industry revenue:
#
# $0bn$4bn$8bn$12bn$16bnValue
# Source: IBIS World
# Total Imports
# $17.4bn’19-’24 1.4 %
# ’24-’29 0.0 %
# Total Exports
# $3.7bn’19-’24 4.3 %
# ’24-’29 1.6 %
# Trade Balance
# Net
# ImporterDeficit: $- 13.7bn
#
# To find the percentage of the industry's imports due to the net importer deficit, I can divide the net importer deficit by the total imports and multiply by 100:
#
# ($-13.7bn ÷ $17.4bn) x 100% ≈ 78.7%
#
# So, approximately 78.7% of the industry's imports are due to the net importer deficit.
#
# Result 33
# Question: Here is a rewritten version of the question:
#
# "What advantage do companies gain from outsourcing low-value-added products?"
#
# This version is shorter and more indirect, requiring the reader to make the same logical connections as the original question.
# Answer: Based on the context, I would answer:
#
# Companies gain the advantage of being able to focus on high-value-added products and services, while outsourcing low-value-added products to specialized companies that can handle them more efficiently and cost-effectively.
#
# This is implied in the context, where it mentions that "incumbent enterprises often outsource contracts to non-employees to fulfill distribution" and that "specialized freight trucking companies that offer low-cost transportation services are protected from buyer power as their clients are less likely to develop an in-house transportation department".
#
# Result 34
# Question: Here is a rewritten version of the question:
#
# "What shields wheat farmers from market downturns?"
#
# This version conveys the same meaning as the original question, but in a more indirect and concise manner. It still requires the reader to make logical connections and inferences, but in a more subtle way.
# Answer: Based on the provided context, it appears that wheat farmers in Canada are shielded from market downturns by several factors:
#
# 1. **Low concentration of the market**: The wheat farming industry in Canada is characterized by a low concentration of market share, with many small, family-owned farms operating locally. This decentralized structure limits the ability of any single entity to dominate the market and makes it challenging for large corporate farms to consolidate power.
# 2. **Geographical diversity**: Canada's vast and varied geography results in different regions being suited for wheat farming, dispersing production geographically and preventing dominance by a few large players.
# 3. **Regional crop rotation and environmental conditions**: Regional crop rotation and environmental conditions necessitate diverse farming approaches, reducing the likelihood of market concentration.
# 4. **Low buyer power**: Consumers tend to choose the lowest-priced product when all other factors are equal, which puts pressure on wheat farmers to keep prices relatively low. However, this also means that wheat farmers have some flexibility to adjust their prices in response to market conditions.
# 5. **Moderate supplier power**: While upstream suppliers have consolidated, limiting upstream competition, wheat farmers can still negotiate prices with suppliers or switch suppliers to reduce costs.
#
# These factors combined create a relatively stable market environment for wheat farmers in Canada, shielding them
# Result 35
# Question: Here's a rewritten version of the question:
#
# "What market structures are vulnerable to fragmentation due to low barriers to entry, and how does this affect market concentration?"
#
# I've used abbreviations like "vulnerable to fragmentation" instead of "hinder the concentration of market share" and "affect market concentration" instead of "what is the impact of this hindrance on the industry's market share concentration". This makes the question more concise and indirect while retaining the essence of the original question.
# Answer: Based on the provided context, the market structures that are vulnerable to fragmentation due to low barriers to entry are:
#
# 1. Long-distance freight trucking in Canada: The industry has low barriers to entry, making it easy for small-scale businesses and non-employers to enter the market. This has led to the addition of over 5,000 non-employer establishments since 2018, resulting in a low concentration of market share.
# 2. Corn farming in Canada: The industry is predominantly made up of small companies and family-owned farms that operate locally, focusing on niche market segments. This decentralized structure leads to a thinly distributed market share, limiting any single entity's ability to dominate and making it challenging for large corporate farms to consolidate power.
#
# In both cases, the low barriers to entry have contributed to the fragmentation of the market, making it difficult for any single entity to establish a significant market share. This is consistent with the trends observed in other trucking industries, where fragmentation is a common characteristic.
#
# Result 36
# Question: Here is the rewritten question:
#
# "What expenses hurt small trucking firms most with new tech?
# Answer: Based on the provided context, it appears that the following expenses hurt small trucking firms most with new tech:
#
# 1. Higher capital costs for specialized equipment, such as sand and clay-carrying trailers or vacuum trailers, which can cost upwards of $110,000 to $140,000.
# 2. Increased depreciation expenses due to technological innovations that drive down the salvage value of older truck models, causing small carriers to operate outdated trucks for a longer duration.
# 3. Higher purchase costs for new vehicles equipped with advanced technology, such as sensors, load monitors, and fuel-efficient engines, which can drive up the costs of new vehicles.
# 4. Rising costs of labor, as companies must invest in training and equipment to maintain a skilled workforce, and also offer competitive salaries to attract and retain drivers.
# 5. Higher costs of fuel and replacement parts, which constitute a significant portion of expenses for trucking firms.
#
# These expenses can create barriers to entry for new small trucking firms and make it challenging for them to remain competitive in the industry.
#
# Result 37
# Question: Here's a rewritten version of the question:
#
# "What kind of place do companies that outsource low-value work often set up shop in, and why?"
#
# I've used abbreviations like "low-value work" instead of "low-value-added products" and "set up shop in" instead of "operate", to make the question shorter and more concise. I've also rephrased the question to make it more indirect and conversational.
# Answer: Unfortunately, I don't have any information about companies that outsource low-value work. The context provided is about IBISWorld, which specializes in industry research, but it doesn't mention anything about companies that outsource low-value work.
#
# Result 38
# Question: Here's a rewritten version of the question:
#
# "What's the largest share of Canada's transportation & warehousing market?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing the phrase "in the transportation and warehousing industry"
# * Using an abbreviation ("&" for "and")
# * Changing the wording to make it more concise and natural-sounding.
# Answer: According to the provided context, the largest share of Canada's transportation & warehousing market is the domestic market, which accounts for 72.1% of the industry's revenue.
#
# Result 39
# Question: Here's a rewritten version of the question:
#
# "When did Canada's manufacturing revenue growth spike?"
#
# I've used abbreviations like "Canada's" and "spike" to make the question shorter and more concise, while still conveying the same meaning as the original question.
# Answer: Unfortunately, I don't have enough information to answer that question. The provided context only mentions the revenue growth of the auto parts manufacturing industry in Canada, but it doesn't provide a specific answer to when the revenue growth spiked.
#
# Result 40
# Question: Here's a rewritten version of the question:
#
# "What Canadian ag sectors use tech to stay ahead?"
#
# This version conveys the same meaning as the original question but in a more indirect and concise manner. I've used abbreviations like "ag" for "agricultural" and "tech" for "technological innovation" to make the question shorter.
# Answer: Based on the provided context, it appears that the Canadian corn farming sector uses technology to stay ahead. Specifically, the adoption of precision farming and other industry technologies helps farmers modernize operations and boost efficiency.
#
# Additionally, the wheat farming sector in Canada also uses technology to some extent, as mentioned in the context that farms can improve efficiency and production by investing in automated equipment.
#
# However, it's worth noting that the context does not provide a comprehensive list of all Canadian ag sectors that use technology to stay ahead.
#
# Result 41
# Question: Here's a rewritten version of the question:
#
# "How do Canadian wheat farmers manage fertilizer costs to stay competitive?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "Canadian" instead of "in Canada")
# * Focusing on the main issue (managing fertilizer costs) rather than the broader context (balancing impact on profit margins)
# Answer: Based on the provided context, it appears that Canadian wheat farmers manage fertilizer costs by:
#
# * Limiting expenses to keep their own prices competitive
# * Focusing on leveraging economies of scope, such as growing other plants like substitute grains, to better navigate changes in the relative popularity of wheat
# * Taking advantage of government subsidies and other grants to financially assist farmers
# * Having long-term contracts with down-stream processors, including flour millers, to secure revenue when product differentiation is low
#
# However, it's worth noting that the context also mentions that volatile fertilizer prices have limited profit growth for Canadian wheat farmers, and that rising costs have forced farmers to be especially focused on limiting expenses.
#
# Result 42
# Question: Here's a rewritten version of the question:
#
# "How do large companies with scale advantages compete with trucking specialists?"
#
# I've used abbreviations like "large companies" instead of "companies with superior economies of scale and access to capital" and "truckers" instead of "specialized freight trucking services" to make the question shorter and more indirect.
# Answer: Large companies with scale advantages often compete with trucking specialists by:
#
# * Subcontracting operations to local truckers, allowing them to focus on larger contracts and more complex logistics
# * Targeting small and medium-sized enterprises (SMEs) for buyouts, expanding their operations and market share
# * Offering diversified services, such as truckload, less-than-truckload, and general freight distribution, to capture a broader market
# * Investing in technology and systems to improve route efficiency and reduce costs, making them more competitive with specialized services
# * Focusing on niche markets and developing specialized expertise to differentiate themselves from larger companies
#
# However, the fragmented nature of the industry, with many small and non-employer businesses operating in local areas, makes it challenging for large companies to establish a significant market share.
#
# Result 43
# Question: Here's a rewritten version of the question:
#
# "When do wheat farmers adjust their product mix, and how does it affect price competition?"
#
# I've kept the essence of the original question, but made it more indirect and concise by:
#
# * Removing unnecessary words and phrases
# * Using abbreviations (e.g. "do" instead of "in which market conditions")
# * Focusing on the key concepts (adjusting product mix and price competition)
# Answer: Based on the provided context, it appears that wheat farmers adjust their product mix in response to changes in market conditions. However, the context does not provide a specific answer to the question of when wheat farmers adjust their product mix.
#
# The context does mention that successful farms have the ability to alter the balance between corn crops and other products in response to changes in market conditions for farm viability. This suggests that wheat farmers may adjust their product mix in response to changes in market conditions, but it does not provide a specific answer to the question.
#
# Regarding the effect of adjusting product mix on price competition, the context mentions that wheat farmers have to contend with a relatively thin profit margin and rising costs, which forces them to be especially focused on limiting expenses to keep their own prices competitive. This suggests that adjusting product mix may be a way for wheat farmers to maintain price competition, but it does not provide a direct answer to the question.
#
# Therefore, I would say that I don't know the specific answer to the question of when wheat farmers adjust their product mix and how it affects price competition.
# Result 44
# Question: Here is a rewritten version of the question:
#
# "What strategy helps farmers stabilize prices and supply?"
#
# This version conveys the same meaning as the original question but in a more indirect and concise manner.
# Answer: Based on the provided context, the strategy that helps farmers stabilize prices and supply is:
#
# "Develop a clear market position and use new technology to contain costs and boost productivity."
#
# This is mentioned in the context of "Key Success Factors" under the section "How do successful businesses handle concentration?" It suggests that establishing a distinct market position and implementing the latest agricultural technologies and precision agriculture practices can help farmers differentiate their products, attract unique customer segments, and create brand loyalty, ultimately leading to stabilized prices and supply.
#
# Result 45
# Question: How do businesses of all types use IBISWorld's research?
# Answer: According to the provided context, businesses of all types use IBISWorld's research to gain quick and actionable insights on industries around the world. This allows them to spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.
#
# CPU times: user 2.02 s, sys: 105 ms, total: 2.12 s
# Wall time: 2min 27s

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %% [markdown]
# #### Preview the final test set

# %%
dataset.to_pandas()
# Out:
#                                              question  \
# 0   Here is a question that can be fully answered ...
# 1   Here is a question that can be fully answered ...
# 2   Here is a question that can be fully answered ...
# 3   Here is a question that can be fully answered ...
# 4   Here is a question that can be fully answered ...
# 5   Here is a question that can be fully answered ...
# 6   Here is a question that can be fully answered ...
# 7   Here is a question that can be fully answered ...
# 8   Here is a question that can be fully answered ...
# 9   Here is a question that can be fully answered ...
# 10  Here is a question that can be fully answered ...
# 11  Here is the question that can be fully answere...
# 12  Here is a question that can be fully answered ...
# 13  Here is a question that can be fully answered ...
# 14  Here is a question that can be fully answered ...
# 15  Here is a question that can be fully answered ...
# 16  Here is a question that can be fully answered ...
# 17  Here is a question that can be fully answered ...
# 18  Here is a question that can be fully answered ...
# 19  Here is a question that can be fully answered ...
# 20  Here is a question that can be fully answered ...
# 21  Here is a question that can be fully answered ...
# 22  Here is a question that can be fully answered ...
# 23  Here is a question that can be fully answered ...
# 24  Here is a question that can be fully answered ...
# 25  Here is the rewritten question:\n\n"Where is N...
# 26  Here is a rewritten version of the question:\n...
# 27  Here is a rewritten version of the question:\n...
# 28  Here is the rewritten question:\n\n"What's the...
# 29  How does IoT-driven route optimization affect ...
# 30  Here is the rewritten question:\n\n"What law t...
# 31  Here is a rewritten version of the question:\n...
# 32  How much of the industry's imports is due to t...
# 33  Here is a rewritten version of the question:\n...
# 34  Here is a rewritten version of the question:\n...
# 35  Here's a rewritten version of the question:\n\...
# 36  Here is the rewritten question:\n\n"What expen...
# 37  Here's a rewritten version of the question:\n\...
# 38  Here's a rewritten version of the question:\n\...
# 39  Here's a rewritten version of the question:\n\...
# 40  Here's a rewritten version of the question:\n\...
# 41  Here's a rewritten version of the question:\n\...
# 42  Here's a rewritten version of the question:\n\...
# 43  Here's a rewritten version of the question:\n\...
# 44  Here is a rewritten version of the question:\n...
# 45  How do businesses of all types use IBISWorld's...
#
#                                              contexts  \
# 0   [Buy er & Supplier P ower\nSour ce: IBIS World...
# 1   [Related T erms\nLIGHT -DUTY VEHICLE\nA passen...
# 2   [ lik e obesity and canc er\nhave dampened dem...
# 3   [pass higher input pric es on to buy ers, lead...
# 4   [Major Mark ets Segmen tation\nIndus try r eve...
# 5   [ on tr ade, which has impr oved following the...
# 6   [Major Mark ets Segmen tation\nIndus try r eve...
# 7   [transit o ver driving.\n•In fact, mor e than ...
# 8   [activity and impr oved in ventory c ontrol. T...
# 9   [Ontario has the l argest spr ead o f business...
# 10  [Evolving c onsumer t astes s teer c orn deman...
# 11  [About\nIBISWorld specializ es in indus try re...
# 12  [costs on to buy ers, cr eating s trong r even...
# 13  [, lik e the Unit ed S tates, Japan, German y ...
# 14  [About\nIBISWorld specializ es in indus try re...
# 15  [Produc ts and Mark ets\nKey Takeaways\nClima ...
# 16  [Previous suppl y chain chal lenges ar e pr om...
# 17  [Major Mark ets\nWha t’s influencing demand fr...
# 18  [Whea t farmer s ha ve to contend with a r ela...
# 19  [Financial Benchmark s\nKey Takeaways\nVolatil...
# 20  [ acturing sec tor.\nThe pr ovinc e is rich in...
# 21  [How do suc cessful businesses c ompe te with ...
# 22  [•The indus try's specializ ed na ture often c...
# 23  [Key Suc cess F actors\nHow do suc cessful bus...
# 24  [Low\nLow Steady\nModer ate Incr easing\nMatur...
# 25  [Wha t's impac ting Ne wRoads A utomo tive Gr ...
# 26  [Inspec tion A genc y.\nStart-up Co sts\n•Corn...
# 27  [In House\n•Access t o capit al and e xpanding...
# 28  [Empl oyees\nTotal number o f empl oyees and a...
# 29  [Produc ts & Servic es Segmen tation\nIndus tr...
# 30  [Legal\n•Whea t farmer s mus t compl y with al...
# 31  [IBISWorld helps y ou find the\nindus try in f...
# 32  [Interna tional T rade: Import s\nConc entrati...
# 33  [How do suc cessful businesses c ompe te with ...
# 34  [Key Suc cess F actors\nHow do suc cessful bu...
# 35  [Compe titiv e Forces\nKey Takeaways\nLow barr...
# 36  [•The indus try's specializ ed na ture often c...
# 37  [Ontario has the l argest spr ead o f business...
# 38  [Companies\nNo singl e compan y ac counts for ...
# 39  [Indus try Da ta\nAnnual Change\nYearRevenue\n...
# 40  [Key Suc cess F actors\nHow do suc cessful bus...
# 41  [manageabl e. Combined with capit al in vestme...
# 42  [sensitiv e goods o ver short dis tances.\nRai...
# 43  [Key Suc cess F actors\nHow do suc cessful bu...
# 44  [Key Suc cess F actors\nHow do suc cessful bu...
# 45  [About\nIBISWorld specializ es in indus try re...
#
#                                          ground_truth evolution_type  \
# 0   Buyers can select services with the expectatio...         simple
# 1                     6,350 kilograms (14,000 pounds)         simple
# 2   Health-conscious customers are willing to pay ...         simple
# 3   Higher input prices are passed on to buyers, l...         simple
# 4   According to the IBIS World source, 35.9% of i...         simple
# 5   The dismantling of the Canadian Wheat Board in...         simple
# 6   Yes, rising corn production in Canada is expec...         simple
# 7   70.0% of Canada's population has access to pub...         simple
# 8   The just-in-time inventory management system c...         simple
# 9   The benefits of selecting regions with optimal...         simple
# 10  The main factors driving the shift in corn dem...         simple
# 11  Businesses gain quick and actionabl e insigh t...         simple
# 12  The expected Compound Annual Growth Rate (CAGR...         simple
# 13  Japan, Germany, and South Korea are preferred ...         simple
# 14  IBISWorld industry research helps businesses o...         simple
# 15  The ongoing easing of monetary policy has begu...         simple
# 16  The trend of merchants sourcing goods from glo...         simple
# 17  The major customers of auto parts manufacturer...         simple
# 18  Wheat farmers have to contend with a relativel...         simple
# 19  The main factors that challenge profit stabili...         simple
# 20  The manufacturing sector in Canada is rich in ...         simple
# 21  The benefit of investing in research and devel...         simple
# 22  Non-employers face challenges in managing labo...         simple
# 23  The benefit of using efficient manufacturing t...         simple
# 24  Economic volatility fueled by inflationary pre...         simple
# 25  The answer to given question is not present in...      reasoning
# 26  The answer to given question is not present in...      reasoning
# 27  Access to capital and expanding operations are...      reasoning
# 28  The answer to given question is not present in...      reasoning
# 29  The answer to given question is not present in...      reasoning
# 30  The Canada Grain Act ties Canada's grain quali...      reasoning
# 31  The answer to given question is not present in...      reasoning
# 32  The answer to given question is not present in...      reasoning
# 33  Companies gain a competitive price advantage f...      reasoning
# 34  Wheat farmers can shield themselves from marke...      reasoning
# 35  The market structures vulnerable to fragmentat...  multi_context
# 36  The answer to given question is not present in...  multi_context
# 37  Companies that outsource low-value work often ...  multi_context
# 38  The answer to given question is not present in...  multi_context
# 39  The answer to given question is not present in...  multi_context
# 40  The answer to given question is not present in...  multi_context
# 41  Canadian wheat farmers manage fertilizer costs...  multi_context
# 42  Large companies with scale advantages compete ...  multi_context
# 43  The answer to given question is not present in...  multi_context
# 44  Establishing supply contracts for key inputs h...  multi_context
# 45  IBISWorld's research helps businesses of all t...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 1   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 2   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 3   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 4   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 5   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 6   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 7   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 8   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 9   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 10  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 11  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 12  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 13  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 14  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 15  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 16  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 17  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 18  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 19  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 20  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 21  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 22  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 23  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 24  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 25  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 26  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 27  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 28  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 29  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 30  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 31  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 32  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 33  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 34  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 35  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 36  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 37  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 38  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 39  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 40  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 41  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 42  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 43  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 44  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 45  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
#
#                                                answer
# 0   According to the context, buyers in the shippi...
# 1   The weight limit for a light-duty vehicle is l...
# 2   Health-conscious customers are willing to pay ...
# 3   According to the context, higher input prices ...
# 4   According to the IBIS World report, the human ...
# 5   No, the context does not mention the dismantli...
# 6   Yes, rising corn production in Canada is expec...
# 7   According to the text, approximately 70.0% of ...
# 8   The just-in-time (JIT) inventory management sy...
# 9   According to the text, the benefits of selecti...
# 10  According to the context, the main factors dri...
# 11  The context does not explicitly state the bene...
# 12  According to the outlook, the expected Compoun...
# 13  According to the context, international compan...
# 14  According to the context, IBISWorld industry r...
# 15  The ongoing easing of monetary policy is expec...
# 16  The trend impacting long-distance freight truc...
# 17  The major customers of auto parts manufacturer...
# 18  According to the context, the main challenges ...
# 19  The main factors that challenge profit stabili...
# 20  According to the context, natural resources pl...
# 21  The benefit of investing in research and devel...
# 22  According to the context, the challenges faced...
# 23  According to the context, the benefit of using...
# 24  According to the context, some factors that ha...
# 25  According to the context, NewRoads Automotive ...
# 26  Based on the provided context, it appears that...
# 27  According to the context, in-house logistics f...
# 28  I don't know. The provided context does not in...
# 29  I don't know. The provided context does not me...
# 30  According to the context, the law that ties Ca...
# 31  According to the disclaimer, to the extent per...
# 32  Based on the context, I can see that the indus...
# 33  Based on the context, I would answer:\n\nCompa...
# 34  Based on the provided context, it appears that...
# 35  Based on the provided context, the market stru...
# 36  Based on the provided context, it appears that...
# 37  Unfortunately, I don't have any information ab...
# 38  According to the provided context, the largest...
# 39  Unfortunately, I don't have enough information...
# 40  Based on the provided context, it appears that...
# 41  Based on the provided context, it appears that...
# 42  Large companies with scale advantages often co...
# 43  Based on the provided context, it appears that...
# 44  Based on the provided context, the strategy th...
# 45  According to the provided context, businesses ...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - *[Faithfulness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/faithfulness.html)*: Are all the claims that are made in the answer inferred from the given context(s)?
# - *[Context Precision](https://docs.ragas.io/en/v0.1.21/concepts/metrics/context_precision.html)*: Did our retriever return good results that matched the question it was being asked?
# - *[Answer Correctness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/answer_correctness.html)*: Was the generated answer correct? Was it complete?

# %%
# %%time
score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/138 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# CPU times: user 9.59 s, sys: 253 ms, total: 9.84 s
# Wall time: 2min 21s
#                                              question  \
# 0   Here is a question that can be fully answered ...
# 1   Here is a question that can be fully answered ...
# 2   Here is a question that can be fully answered ...
# 3   Here is a question that can be fully answered ...
# 4   Here is a question that can be fully answered ...
# 5   Here is a question that can be fully answered ...
# 6   Here is a question that can be fully answered ...
# 7   Here is a question that can be fully answered ...
# 8   Here is a question that can be fully answered ...
# 9   Here is a question that can be fully answered ...
# 10  Here is a question that can be fully answered ...
# 11  Here is the question that can be fully answere...
# 12  Here is a question that can be fully answered ...
# 13  Here is a question that can be fully answered ...
# 14  Here is a question that can be fully answered ...
# 15  Here is a question that can be fully answered ...
# 16  Here is a question that can be fully answered ...
# 17  Here is a question that can be fully answered ...
# 18  Here is a question that can be fully answered ...
# 19  Here is a question that can be fully answered ...
# 20  Here is a question that can be fully answered ...
# 21  Here is a question that can be fully answered ...
# 22  Here is a question that can be fully answered ...
# 23  Here is a question that can be fully answered ...
# 24  Here is a question that can be fully answered ...
# 25  Here is the rewritten question:\n\n"Where is N...
# 26  Here is a rewritten version of the question:\n...
# 27  Here is a rewritten version of the question:\n...
# 28  Here is the rewritten question:\n\n"What's the...
# 29  How does IoT-driven route optimization affect ...
# 30  Here is the rewritten question:\n\n"What law t...
# 31  Here is a rewritten version of the question:\n...
# 32  How much of the industry's imports is due to t...
# 33  Here is a rewritten version of the question:\n...
# 34  Here is a rewritten version of the question:\n...
# 35  Here's a rewritten version of the question:\n\...
# 36  Here is the rewritten question:\n\n"What expen...
# 37  Here's a rewritten version of the question:\n\...
# 38  Here's a rewritten version of the question:\n\...
# 39  Here's a rewritten version of the question:\n\...
# 40  Here's a rewritten version of the question:\n\...
# 41  Here's a rewritten version of the question:\n\...
# 42  Here's a rewritten version of the question:\n\...
# 43  Here's a rewritten version of the question:\n\...
# 44  Here is a rewritten version of the question:\n...
# 45  How do businesses of all types use IBISWorld's...
#
#                                              contexts  \
# 0   [Buy er & Supplier P ower\nSour ce: IBIS World...
# 1   [Related T erms\nLIGHT -DUTY VEHICLE\nA passen...
# 2   [ lik e obesity and canc er\nhave dampened dem...
# 3   [pass higher input pric es on to buy ers, lead...
# 4   [Major Mark ets Segmen tation\nIndus try r eve...
# 5   [ on tr ade, which has impr oved following the...
# 6   [Major Mark ets Segmen tation\nIndus try r eve...
# 7   [transit o ver driving.\n•In fact, mor e than ...
# 8   [activity and impr oved in ventory c ontrol. T...
# 9   [Ontario has the l argest spr ead o f business...
# 10  [Evolving c onsumer t astes s teer c orn deman...
# 11  [About\nIBISWorld specializ es in indus try re...
# 12  [costs on to buy ers, cr eating s trong r even...
# 13  [, lik e the Unit ed S tates, Japan, German y ...
# 14  [About\nIBISWorld specializ es in indus try re...
# 15  [Produc ts and Mark ets\nKey Takeaways\nClima ...
# 16  [Previous suppl y chain chal lenges ar e pr om...
# 17  [Major Mark ets\nWha t’s influencing demand fr...
# 18  [Whea t farmer s ha ve to contend with a r ela...
# 19  [Financial Benchmark s\nKey Takeaways\nVolatil...
# 20  [ acturing sec tor.\nThe pr ovinc e is rich in...
# 21  [How do suc cessful businesses c ompe te with ...
# 22  [•The indus try's specializ ed na ture often c...
# 23  [Key Suc cess F actors\nHow do suc cessful bus...
# 24  [Low\nLow Steady\nModer ate Incr easing\nMatur...
# 25  [Wha t's impac ting Ne wRoads A utomo tive Gr ...
# 26  [Inspec tion A genc y.\nStart-up Co sts\n•Corn...
# 27  [In House\n•Access t o capit al and e xpanding...
# 28  [Empl oyees\nTotal number o f empl oyees and a...
# 29  [Produc ts & Servic es Segmen tation\nIndus tr...
# 30  [Legal\n•Whea t farmer s mus t compl y with al...
# 31  [IBISWorld helps y ou find the\nindus try in f...
# 32  [Interna tional T rade: Import s\nConc entrati...
# 33  [How do suc cessful businesses c ompe te with ...
# 34  [Key Suc cess F actors\nHow do suc cessful bu...
# 35  [Compe titiv e Forces\nKey Takeaways\nLow barr...
# 36  [•The indus try's specializ ed na ture often c...
# 37  [Ontario has the l argest spr ead o f business...
# 38  [Companies\nNo singl e compan y ac counts for ...
# 39  [Indus try Da ta\nAnnual Change\nYearRevenue\n...
# 40  [Key Suc cess F actors\nHow do suc cessful bus...
# 41  [manageabl e. Combined with capit al in vestme...
# 42  [sensitiv e goods o ver short dis tances.\nRai...
# 43  [Key Suc cess F actors\nHow do suc cessful bu...
# 44  [Key Suc cess F actors\nHow do suc cessful bu...
# 45  [About\nIBISWorld specializ es in indus try re...
#
#                                          ground_truth evolution_type  \
# 0   Buyers can select services with the expectatio...         simple
# 1                     6,350 kilograms (14,000 pounds)         simple
# 2   Health-conscious customers are willing to pay ...         simple
# 3   Higher input prices are passed on to buyers, l...         simple
# 4   According to the IBIS World source, 35.9% of i...         simple
# 5   The dismantling of the Canadian Wheat Board in...         simple
# 6   Yes, rising corn production in Canada is expec...         simple
# 7   70.0% of Canada's population has access to pub...         simple
# 8   The just-in-time inventory management system c...         simple
# 9   The benefits of selecting regions with optimal...         simple
# 10  The main factors driving the shift in corn dem...         simple
# 11  Businesses gain quick and actionabl e insigh t...         simple
# 12  The expected Compound Annual Growth Rate (CAGR...         simple
# 13  Japan, Germany, and South Korea are preferred ...         simple
# 14  IBISWorld industry research helps businesses o...         simple
# 15  The ongoing easing of monetary policy has begu...         simple
# 16  The trend of merchants sourcing goods from glo...         simple
# 17  The major customers of auto parts manufacturer...         simple
# 18  Wheat farmers have to contend with a relativel...         simple
# 19  The main factors that challenge profit stabili...         simple
# 20  The manufacturing sector in Canada is rich in ...         simple
# 21  The benefit of investing in research and devel...         simple
# 22  Non-employers face challenges in managing labo...         simple
# 23  The benefit of using efficient manufacturing t...         simple
# 24  Economic volatility fueled by inflationary pre...         simple
# 25  The answer to given question is not present in...      reasoning
# 26  The answer to given question is not present in...      reasoning
# 27  Access to capital and expanding operations are...      reasoning
# 28  The answer to given question is not present in...      reasoning
# 29  The answer to given question is not present in...      reasoning
# 30  The Canada Grain Act ties Canada's grain quali...      reasoning
# 31  The answer to given question is not present in...      reasoning
# 32  The answer to given question is not present in...      reasoning
# 33  Companies gain a competitive price advantage f...      reasoning
# 34  Wheat farmers can shield themselves from marke...      reasoning
# 35  The market structures vulnerable to fragmentat...  multi_context
# 36  The answer to given question is not present in...  multi_context
# 37  Companies that outsource low-value work often ...  multi_context
# 38  The answer to given question is not present in...  multi_context
# 39  The answer to given question is not present in...  multi_context
# 40  The answer to given question is not present in...  multi_context
# 41  Canadian wheat farmers manage fertilizer costs...  multi_context
# 42  Large companies with scale advantages compete ...  multi_context
# 43  The answer to given question is not present in...  multi_context
# 44  Establishing supply contracts for key inputs h...  multi_context
# 45  IBISWorld's research helps businesses of all t...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 1   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 2   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 3   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 4   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 5   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 6   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 7   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 8   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 9   [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 10  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 11  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 12  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 13  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 14  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 15  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 16  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 17  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 18  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 19  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 20  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 21  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 22  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 23  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 24  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 25  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 26  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 27  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 28  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 29  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 30  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 31  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 32  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 33  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 34  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 35  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 36  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 37  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 38  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 39  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 40  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 41  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 42  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 43  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 44  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
# 45  [{'file_name': '/projects/RAG2/scotia-2/Datase...          True
#
#                                                answer  faithfulness  \
# 0   According to the context, buyers in the shippi...           NaN
# 1   The weight limit for a light-duty vehicle is l...      1.000000
# 2   Health-conscious customers are willing to pay ...      1.000000
# 3   According to the context, higher input prices ...      1.000000
# 4   According to the IBIS World report, the human ...      0.333333
# 5   No, the context does not mention the dismantli...      0.000000
# 6   Yes, rising corn production in Canada is expec...           NaN
# 7   According to the text, approximately 70.0% of ...      0.500000
# 8   The just-in-time (JIT) inventory management sy...      1.000000
# 9   According to the text, the benefits of selecti...           NaN
# 10  According to the context, the main factors dri...           NaN
# 11  The context does not explicitly state the bene...           NaN
# 12  According to the outlook, the expected Compoun...      1.000000
# 13  According to the context, international compan...      1.000000
# 14  According to the context, IBISWorld industry r...      1.000000
# 15  The ongoing easing of monetary policy is expec...           NaN
# 16  The trend impacting long-distance freight truc...      1.000000
# 17  The major customers of auto parts manufacturer...           NaN
# 18  According to the context, the main challenges ...           NaN
# 19  The main factors that challenge profit stabili...           NaN
# 20  According to the context, natural resources pl...           NaN
# 21  The benefit of investing in research and devel...      0.666667
# 22  According to the context, the challenges faced...      0.333333
# 23  According to the context, the benefit of using...      0.333333
# 24  According to the context, some factors that ha...      0.666667
# 25  According to the context, NewRoads Automotive ...      1.000000
# 26  Based on the provided context, it appears that...           NaN
# 27  According to the context, in-house logistics f...           NaN
# 28  I don't know. The provided context does not in...      0.000000
# 29  I don't know. The provided context does not me...      0.500000
# 30  According to the context, the law that ties Ca...      1.000000
# 31  According to the disclaimer, to the extent per...      0.750000
# 32  Based on the context, I can see that the indus...      0.500000
# 33  Based on the context, I would answer:\n\nCompa...           NaN
# 34  Based on the provided context, it appears that...           NaN
# 35  Based on the provided context, the market stru...           NaN
# 36  Based on the provided context, it appears that...           NaN
# 37  Unfortunately, I don't have any information ab...      1.000000
# 38  According to the provided context, the largest...      0.000000
# 39  Unfortunately, I don't have enough information...      0.750000
# 40  Based on the provided context, it appears that...           NaN
# 41  Based on the provided context, it appears that...      1.000000
# 42  Large companies with scale advantages often co...      1.000000
# 43  Based on the provided context, it appears that...           NaN
# 44  Based on the provided context, the strategy th...           NaN
# 45  According to the provided context, businesses ...      0.750000
#
#     context_precision  answer_correctness
# 0                 1.0                 NaN
# 1                 1.0            0.700070
# 2                 1.0            0.550000
# 3                 1.0            0.992848
# 4                 1.0            0.495778
# 5                 1.0            0.597126
# 6                 1.0                 NaN
# 7                 1.0            0.744149
# 8                 1.0            0.608877
# 9                 1.0                 NaN
# 10                1.0                 NaN
# 11                1.0            0.616521
# 12                1.0            0.996577
# 13                1.0            0.653834
# 14                1.0            0.691760
# 15                1.0                 NaN
# 16                1.0            0.608485
# 17                1.0                 NaN
# 18                1.0                 NaN
# 19                1.0            0.234414
# 20                1.0                 NaN
# 21                1.0            0.999792
# 22                1.0            0.714986
# 23                1.0                 NaN
# 24                1.0            0.435437
# 25                0.0            0.459609
# 26                0.0            0.570316
# 27                1.0                 NaN
# 28                0.0            0.399516
# 29                0.0            0.795195
# 30                1.0            0.837556
# 31                0.0            0.766356
# 32                0.0            0.425894
# 33                1.0                 NaN
# 34                1.0                 NaN
# 35                1.0                 NaN
# 36                0.0                 NaN
# 37                1.0                 NaN
# 38                0.0            0.692090
# 39                0.0            0.386326
# 40                0.0                 NaN
# 41                0.5            0.574947
# 42                1.0            0.720244
# 43                0.0            0.510361
# 44                1.0                 NaN
# 45                1.0            0.964830

# %%
score["answer_correctness"].mean()
# Out:
# 0.6463411575905084

# %%
score["faithfulness"].mean()
# Out:
# 0.70679012345679

# %%
#"Meta-Llama-3.1-8B-Instruct"
#chunksize, answer correctness, faithfulness, number of question
#10000, 0.592, 0.698, 50
# 5000, 0.617, 0.700, 50
# 3500, 0.677, 0.734, 50
# 3000, 0.688, 0.800, 50
# 2000, 0.629, 0.742, 50
# 1000, 0.644, 0.703, 50
#  500, 0.619, 0.503, 50
#  250, 0.594, 0.527, 50

# %%
2+2
# Out:
# 4
